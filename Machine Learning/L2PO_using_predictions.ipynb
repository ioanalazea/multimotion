# %% [markdown]
# # Leave 2 Participants Out (L2PO)

# %% [markdown]
# The Leave-Two-Participants-Out (L2PO) cross-validation was applied, meaning the model was trained on all participants except two, and then tested on the two that were left-out.

# %%
# IMPORTS
import os
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error
from scipy.stats import pearsonr
import statsmodels.api as sm
from lightgbm import LGBMRegressor
from typing import List
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Defining the directories
home_directory = r"D:/MASTER/Uni of Essex/Disseration/Data-Multimotion"
full_video_directory = r"D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Features-NEW/Full"
intervals_directory = r"D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Features-NEW/Intervals"
ground_truth_directory = r"D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth"
results_directory = r"D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Results"

# %% [markdown]
# **Loading the data** - will be using only Pupil and GSR now.

# %%
# Full Pupil - loading the csv
df_pupil_full = pd.read_csv(os.path.join(full_video_directory, "Not_Interval_60_part_all_stat_features_12062025.csv"))
df_pupil_full.rename(columns={"Participant": "participant", "simuli_name_1": "video"}, inplace=True)
df_pupil_full.drop(columns=['Arousal', 'Valence', 'simuli_name_2','Unnamed: 0'], inplace=True)

# Intervals Pupil - Loading the csv
df_pupil_interval = pd.read_csv(os.path.join(intervals_directory, "Interval_60_part_all_stat_features_01062025.csv"))
df_pupil_interval.rename(columns={"Participant": "participant", "simuli_name_1": "video"}, inplace=True)
df_pupil_interval.drop(columns=['Arousal', 'Valence', 'simuli_name_2', 'Unnamed: 0'], inplace=True)

# Merging the intervals and full GSR features
df_pupil = pd.merge(df_pupil_full, df_pupil_interval, on=['participant', 'video'],
                    suffixes=('_whole', '_interval'))


# Full GSR - Loading the csv
df_gsr_full = pd.read_csv(os.path.join(full_video_directory, "gsr_features.csv"))
df_gsr_full.rename(columns={"ParticipantID": "participant", "StimulusName": "video"}, inplace=True)

# Intervals GSR - Loading the csv
df_gsr_intervals = pd.read_csv(os.path.join(intervals_directory, "gsr_features_intervals.csv"))
df_gsr_intervals.rename(columns={"ParticipantID": "participant", "StimulusName_0": "video"}, inplace=True)

# Merging the intervals and full GSR features
df_gsr = pd.merge(df_gsr_full, df_gsr_intervals, on=['participant', 'video'],
                  suffixes=('_whole', '_interval'))


participant_col = 'participant'
video_col = 'video'

pupil_features = [col for col in df_pupil.columns if col not in [participant_col, video_col]]
gsr_features = [col for col in df_gsr.columns if col not in [participant_col, video_col]]


# Merging df_fer and df_pupil
df = pd.merge( df_gsr,df_pupil, on=['participant', 'video'], how='inner')

# %%
# Checking the number of participants
print('Participants Pupil:', len(df_pupil['participant'].unique()))
print('Participants GSR:', len(df_gsr['participant'].unique()))
print('Participants merged:', len(df['participant'].unique()))
# Out:
# Participants Pupil: 59
# Participants GSR: 59
# Participants merged: 56

# %% [markdown]
# Cleaning the data

# %%
# Get columns with NaNs and sort by number of NaNs
nan_summary = df.isnull().sum()
nan_summary = nan_summary[nan_summary > 0].sort_values(ascending=False)

# Display the columns with NaNs
print(nan_summary.head(100))

# Column names with NaNs from nan_summary
missing_cols = nan_summary.index.tolist()

# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean')  
df[missing_cols] = imputer.fit_transform(df[missing_cols])
# Out:
# corr_kurtosis_whole       1619
# corr_skewness_whole       1619
# corr_auc_whole            1619
# diff_kurtosis_whole       1619
# diff_skewness_whole       1619
# diff_auc_whole            1619
# corr_kurtosis_interval     668
# corr_skewness_interval     668
# corr_auc_interval          668
# diff_kurtosis_interval     668
# diff_skewness_interval     668
# diff_auc_interval          668
# dtype: int64

# %% [markdown]
# **Ground truth**

# %%
# Load full ground truth (this is done only once)
gt_full_set = pd.read_csv(os.path.join(ground_truth_directory, "individual_ground_truth.csv"))

# Renaming so it has the same names as Pupil
gt_full_set.rename(columns={"Participant": "participant", "Stimulus_Name": "video"}, inplace=True)

# Function to load ground truth file excluding one participant for Leave One Participant Out
def load_ground_truth_exclude(participant_id):
    # Construct the file path
    file_path = os.path.join(
        ground_truth_directory,
        f"Leave-one-out/individual_ground_truth_no_{participant_id}.csv"
    )

    try:
        gt_df = pd.read_csv(file_path)
        return gt_df
    except FileNotFoundError:
        print(f"[Warning] Ground truth file not found for participant {participant_id} at: {file_path}")
        return None 
    
# Function to load ground truth file excluding more participants for Leave Two Participants Out
def load_ground_truth_exclude_multiple(participant_ids):
    assert len(participant_ids) == 2, "Exactly two participant IDs are required."

    id_pairs = [
        (participant_ids[0], participant_ids[1]),
        (participant_ids[1], participant_ids[0])
    ]

    for id1, id2 in id_pairs:
        file_path = os.path.join(
            ground_truth_directory,
            f"Leave-two-out/individual_ground_truth_no_{id1}_no_{id2}.csv"
        )
        if os.path.exists(file_path):
            return pd.read_csv(file_path)
    
    print(f"[Warning] Ground truth file not found for participant pair {participant_ids} in either order.")
    return None

# %%
def get_train_test_data_fusion(df, gt_full_set, test_pid, target):
    """
    Get the GT data correctly.
    
    For layer-1 fusion:
    - test_pid is the IgnoredParticipant (unseen at layer 0).
    - We merge ground truth based on PredictedParticipant for evaluation.
    """
    # Select test rows where the IgnoredParticipant matches
    test_data = df[df["IgnoredParticipant"] == test_pid].copy()

    # Merge ground truth using PredictedParticipant
    test_gt = gt_full_set[gt_full_set["participant"].isin(test_data["PredictedParticipant"].unique())]
    test_data = test_data.merge(
        test_gt[["participant", "video", target]],
        left_on=["PredictedParticipant", "video"],
        right_on=["participant", "video"],
        how="inner"
    ).drop(columns=["participant"])  # drop duplicate after merge

    # Training data is all rows where the IgnoredParticipant != test_pid
    train_data = df[df["IgnoredParticipant"] != test_pid].copy()
    pid_gt = load_ground_truth_exclude(test_pid) 
    if pid_gt is not None: 
        pid_gt.rename( columns={"Participant": "participant", "Stimulus_Name": "video"}, 
                      inplace=True )
        
    # Merge ground truth for training using PredictedParticipant
    train_data = train_data.merge(
        pid_gt[["participant", "video", target]],
        left_on=["PredictedParticipant", "video"],
        right_on=["participant", "video"],
        how="inner"
    ).drop(columns=["participant"])

    return train_data, test_data



def get_train_test_data_l2po(df, test_pids, target):
    """Split data into train and test and merge with ground truth for L2PO."""
    test_data = df[df["participant"].isin(test_pids)].copy()
    gt = load_ground_truth_exclude(test_pids[0])

    if gt is not None:
        gt.rename(columns={"Participant": "participant", "Stimulus_Name": "video"}, inplace=True)
        test_gt = gt[gt["participant"].isin(test_pids)]
        test_data = test_data.merge(
            test_gt[["participant", "video", target]],
            on=["participant", "video"],
            how="inner",
        )

    train_data = df[~df["participant"].isin(test_pids)].copy()
    
    pid_gt = load_ground_truth_exclude_multiple(test_pids)
    if pid_gt is not None:
        pid_gt.rename(
            columns={"Participant": "participant", "Stimulus_Name": "video"},
            inplace=True
        )
        train_data = train_data.merge(
            pid_gt[["participant", "video", target]],
            on=["participant", "video"],
            how="inner",
        )
        return train_data, test_data
    else:
        return None, None


def evaluate_fusion_model(y_true, y_pred):
    """Calculate evaluation metrics."""
    rmse = root_mean_squared_error(y_true, y_pred)
    nrmse = rmse / (y_true.max() - y_true.min())
    r2 = r2_score(y_true, y_pred)
    corr, p_val = pearsonr(y_true, y_pred)
    return {"NRMSE": nrmse, "R2": r2, "corr": corr, "p": p_val}

def print_filtered_summary(results_df):
    filtered = results_df[
        (results_df['R2'] > -1.0) &                 # Removes models with extremely poor fit
        (results_df['NRMSE'] < 1.5) &              # Removes predictions with very high error
        (results_df['corr'].abs() > 0.2)           # Keeps only modestly correlated results
    ]
    summary_filtered = filtered[['NRMSE', 'R2', 'corr', 'p']].agg(['mean', 'std'])
    print("\n=== Summary (Excluding Outliers) ===")
    print(f"\nFiltered out {len(results_df) - len(filtered)} out of {len(results_df)} participants.")
    print(summary_filtered.round(4))
    excluded = results_df[~results_df.index.isin(filtered.index)]
    print("\nExcluded participants:")
    print(excluded[['participant', 'NRMSE', 'R2', 'corr']])


def print_fusion_weights_summary(fusion_weights):
    if fusion_weights:
        weights_df = pd.DataFrame(fusion_weights).T
        weights_df.columns = [ 'Pupil_weight', 'GSR_weight']
        print("\nAverage Fusion Weights across Participants:")
        print(weights_df.mean().round(4))

# %%
# GSR parameters and features used for the model
gsr_modality_configs = {
    "GSR_arousal": {
        "params": {
            # SVR
            "kernel": "rbf",
            "degree": 2,
            "gamma": 1e-4,
            "coef0": 1,
            "tol": 5e-3,
            "C": 0.5,
            "epsilon": 0.05,

            # LGBM
            "num_leaves": 31,
            "max_depth": -1,
            "learning_rate": 0.1,
            "n_estimators": 300,
            "min_child_samples": 20,
            "subsample": 0.6,
            "colsample_bytree": 0.6,
        },

        "svr_features": [
            'freqKurtEDA_whole', 'freqKurtEDA_interval', 'entropyWavelet_4_interval', 'medianMFCC_1_whole',
            'meanMFCC_1_interval', 'complexity_interval', 'energyDistribution_4_interval',
            'meanDerivative_whole', 'energyDistribution_0_whole', 'energyDistribution_1_whole',
            'energyDistribution_2_whole', 'energyDistribution_3_whole', 'meanNegativeSecondDerivative_whole',
            'phasicPowers_1_whole'
        ],
        "lgbm_features": [
            "freqKurtEDA_whole", "freqKurtEDA_interval", "freqSkewEDA_whole", "freqSkewEDA_interval",
            "energyDistribution_0_whole", "stdMFCC_12_interval", "stdMFCC_11_whole", "stdMFCC_11_interval",
            "stdMFCC_10_interval", "stdMFCC_12_whole", "spectralPowerBand(0.3-0.4)_interval",
            "energyDistribution_1_whole", "energyDistribution_0_interval",
            "spectralPowerBand(0.4-0.5)_interval", "energyWavelet_3_interval", "energyWavelet_2_interval",
            "sumAreas_interval", "meanNegativeSecondDerivative_whole", "energyDistribution_2_whole",
            "energyDistribution_2_interval", "phasicPowers_1_whole", "kurtMFCC_12_interval",
            "entropyWavelet_0_whole", "stdMFCC_10_whole", "energyDistribution_8_interval",
            "energyWavelet_0_interval", "hoc_5_whole", "skewMFCC_12_interval", "skewMFCC_10_interval",
            "energyDistribution_6_whole", "energyDistribution_8_whole", "medianMFCC_10_interval",
            "activity_interval", "meanMFCC_6_interval", "rmsWavelet_3_interval", "energyWavelet_2_whole",
            "hoc_1_whole", "stdMFCC_1_whole", "spectralPowerBand(0.2-0.3)_interval",
            "meanMFCC_11_interval", "medianMFCC_12_interval", "energyDistribution_4_interval",
            "stdMFCC_9_whole", "skewMFCC_1_interval", "skewMFCC_8_interval", "medianMFCC_2_interval",
            "meanSecondDerivative_interval", "meanMFCC_12_interval", "energyDistribution_4_whole",
            "meanMFCC_7_interval"
        ]
    },
        "GSR_valence": {
        "params": {
            # SVR
            "kernel": "rbf",
            "degree": 2,
            "gamma": 5e-4,
            "coef0": 1,
            "tol": 1e-3,
            "C": 1,
            "epsilon": 5e-1,

            # LGBM
            "num_leaves": 31,
            "max_depth": -1,
            "learning_rate": 0.1,
            "n_estimators": 500,
            "min_child_samples": 40,
            "subsample": 0.6,
            "colsample_bytree": 0.6,
        },
        "svr_features": [
            "freqKurtEDA_whole", "freqKurtEDA_interval","kurtMFCC_2_interval",
            "hoc_0_interval", "skewEDA_interval","skewMFCC_5_interval",
            "skewMFCC_6_interval", "meanPeakAmplitude_interval","stdMFCC_2_interval",
            "stdEDA_interval","meanMFCC_3_interval","meanMFCC_11_interval",
            "rmsWavelet_1_interval","meanMFCC_5_interval","mobility_interval","sppw_whole","energyDistribution_0_interval",
        ],
        "lgbm_features": [
            "freqKurtEDA_whole", "freqKurtEDA_interval","freqSkewEDA_interval",
            "freqSkewEDA_whole","skewMFCC_11_interval","energyWavelet_4_interval",
            "rmsWavelet_4_interval","energyDistribution_0_whole","energyWavelet_0_interval",
            "stdMFCC_11_whole", "meanMFCC_12_whole","stdMFCC_12_whole",
            "energyWavelet_2_interval","energyDistribution_2_interval","spectralPowerBand(0.3-0.4)_interval",
            "minSpectralPower_whole","energyDistribution_6_whole","stdMFCC_4_interval",
            "meanMFCC_12_interval","kurtMFCC_2_interval","energyDistribution_8_interval",
            "energyWavelet_3_interval","spectralPowerBand(0.3-0.4)_whole","kurtMFCC_4_interval",
            "stdMFCC_0_interval","energyWavelet_1_interval","meanSecondDerivative_interval",
            "skewMFCC_12_interval","phasicPowers_0_interval","auc_interval",
            "energyDistribution_4_interval","activity_interval","spectralPowerBand(0.4-0.5)_interval",
            "medianMFCC_11_interval","rmsWavelet_3_interval","stdMFCC_12_interval",
            "medianMFCC_10_interval","skewEDA_interval","stdMFCC_10_whole","rmsWavelet_0_interval",
            "kurtMFCC_0_interval", "medianMFCC_12_interval", "stdMFCC_5_interval","energyDistribution_2_whole",
            "stdMFCC_10_interval","varSpectralPower_interval","hoc_2_whole",
            "energyDistribution_1_whole","kurtMFCC_12_whole","meanSecondDerivative_whole",
        ],
    },
}

# Defining the class for the GSR model (stacked SVR LGBM)
class StackedSvrLgbmModel:
    _lgbm_model: LGBMRegressor
    _svr_model: SVR
    _final_regressor: LinearRegression
    svr_features: List[str]
    lgbm_features: List[str]

    def __init__(self,
                 svr_features: List[str],
                 lgbm_features: List[str],
                 # SVR params
                 kernel: str,
                 degree: int,
                 gamma: float,
                 coef0: float,
                 C: float,
                 tol: float,
                 epsilon: float,
                 # LGBM params
                 num_leaves: int,
                 max_depth: int,
                 learning_rate: float,
                 n_estimators: int,
                 min_child_samples: int,
                 subsample: float,
                 colsample_bytree: float):
        self._lgbm_model = LGBMRegressor(n_estimators=n_estimators, num_leaves=num_leaves, max_depth=max_depth,
                                         learning_rate=learning_rate, colsample_bytree=colsample_bytree,
                                         min_child_samples=min_child_samples, subsample=subsample,
                                         n_jobs=-1, boosting_type='dart', force_col_wise=True, verbosity=-1)
        self._svr_model = SVR(kernel=kernel, degree=degree, gamma=gamma, coef0=coef0, tol=tol, C=C, epsilon=epsilon)
        self._final_regressor = LinearRegression()

        self.svr_features = svr_features
        self.lgbm_features = lgbm_features

    def train_and_val(self, train_df: pd.DataFrame, val_df: pd.DataFrame | None,
                      Y_train: pd.DataFrame) -> pd.DataFrame | None:

        X_train_svr = train_df[self.svr_features].to_numpy()
        X_train_lgbm = train_df[self.lgbm_features].astype(float)

        X_train_lgbm, X_val_lgbm, Y_final_regressor_train, Y_final_regressor_val = train_test_split(
            X_train_lgbm,
            Y_train,
            test_size=0.1,
            random_state=42)
        X_train_svr, X_val_svr, _, _ = train_test_split(X_train_svr,
                                                        Y_train,
                                                        test_size=0.1,
                                                        random_state=42)

        self._lgbm_model.fit(X_train_lgbm, Y_final_regressor_train)
        self._svr_model.fit(X_train_svr, Y_final_regressor_train)

        Y_pred_lgbm_train = self._lgbm_model.predict(X_val_lgbm)
        Y_pred_svr_train = self._svr_model.predict(X_val_svr)
        X_final_regressor_train = np.column_stack([Y_pred_lgbm_train, Y_pred_svr_train])
        self._final_regressor.fit(X_final_regressor_train, Y_final_regressor_val)

        if val_df is not None:
            X_test_svr = val_df[self.svr_features].to_numpy()
            X_test_lgbm = val_df[self.lgbm_features].astype(float)

            Y_pred_lgbm_test = self._lgbm_model.predict(X_test_lgbm)
            Y_pred_svr_test = self._svr_model.predict(X_test_svr)
            X_final_regressor_test = np.column_stack([Y_pred_lgbm_test, Y_pred_svr_test])
            Y_pred = self._final_regressor.predict(X_final_regressor_test)
            return Y_pred

        return None

    def test(self, test_df: pd.DataFrame):
        X_test_svr = test_df[self.svr_features].to_numpy()
        X_test_lgbm = test_df[self.lgbm_features].astype(float)

        Y_pred_lgbm_test = self._lgbm_model.predict(X_test_lgbm)
        Y_pred_svr_test = self._svr_model.predict(X_test_svr)

        X_final_regressor_test = np.column_stack([Y_pred_lgbm_test, Y_pred_svr_test])
        Y_pred = self._final_regressor.predict(X_final_regressor_test)

        return Y_pred

# %% [markdown]
# ## Arousal

# %%
# Loading the pupil arousal parameters
pupil_arousal_params = pd.read_csv(os.path.join(home_directory, "pupil_params_arousal.csv"))

# %%
# List to add all fusion inputs
fusion_inputs = []

participants = df["participant"].unique()

for first_p in participants:
    for second_p in participants:
        if first_p == second_p:
            continue
        
        # One participant is ignored (first_p) and one participant is predicted (second_p)
        print(f"Leave out: {first_p}, {second_p}")
        test_id = second_p

        train_data, test_data = get_train_test_data_l2po(
            df, [first_p, second_p], "Arousal"
        )
        if train_data is None or test_data is None:
            continue

        y_train = train_data["Arousal"].values
        y_test = test_data[test_data["participant"] == test_id]["Arousal"].values
        if len(y_test) == 0:
            continue

        # ---- Pupil model-----
        X_train_pupil = train_data[pupil_features]
        X_test_pupil = test_data[pupil_features]
        
        # Making sure Participant column is treated as string
        pupil_arousal_params['Participant'] = pupil_arousal_params['Participant'].astype(str)

        # Convert test_pid to string for matching
        test_pid_str = str(test_id)

        # Find the participant's best params row
        participant_params_row = pupil_arousal_params[pupil_arousal_params['Participant'] == test_pid_str]

        if participant_params_row.empty:
            print(f"No parameters found for participant {test_pid_str}. Using default.")
            model_pupil = LGBMRegressor(random_state=42)
        else:
            # Drop 'Participant' and convert remaining row to dict
            param_dict = participant_params_row.drop(columns=['Participant']).iloc[0].to_dict()

            # Convert any float to int if needed
            param_dict = {k: int(v) if isinstance(v, float) and v.is_integer() else v for k, v in param_dict.items()}

            # Add random_state explicitly
            param_dict['random_state'] = 42

            # Initialize model with participant's parameters
            model_pupil = LGBMRegressor(**param_dict)
        
        model_pupil.fit(X_train_pupil, y_train)
        test_pupil_preds = model_pupil.predict(X_test_pupil)

        # ----- GSR model -----
        X_train_gsr = train_data[gsr_features]
        X_test_gsr = test_data[gsr_features]
        model_gsr = StackedSvrLgbmModel(
            svr_features=gsr_modality_configs["GSR_arousal"]["svr_features"],
            lgbm_features=gsr_modality_configs["GSR_arousal"]["lgbm_features"],
            **gsr_modality_configs["GSR_arousal"]["params"]
        )
        model_gsr.train_and_val(X_train_gsr, None, y_train)
        test_gsr_preds = model_gsr.test(X_test_gsr)

        # Store the fusion inputs per row in test set (even if more than one row)
        # Get the rows corresponding to the current test participant
        test_rows = test_data[test_data["participant"] == test_id].reset_index(drop=True)
        
        for i in range(len(y_test)):
            fusion_inputs.append({
                "IgnoredParticipant": first_p,
                "PredictedParticipant": test_id,
                "video": test_rows.loc[i, "video"],
                "pupil_pred": test_pupil_preds[i],
                "gsr_pred": test_gsr_preds[i],
            })

# Convert to DataFrame
fusion_df = pd.DataFrame(fusion_inputs)

print(fusion_df)
# Out:
# Leave out: 22DFx, 4FoNM
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '4FoNM'] in either order.
# Leave out: 22DFx, 5BJD3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '5BJD3'] in either order.
# Leave out: 22DFx, 5KB3V
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '5KB3V'] in either order.
# Leave out: 22DFx, 6GSd4
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '6GSd4'] in either order.
# Leave out: 22DFx, 7yqP3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '7yqP3'] in either order.
# Leave out: 22DFx, 9FGka
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '9FGka'] in either order.
# Leave out: 22DFx, A5feTy
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'A5feTy'] in either order.
# Leave out: 22DFx, Bs73
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Bs73'] in either order.
# Leave out: 22DFx, CVgs2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'CVgs2'] in either order.
# Leave out: 22DFx, CoQmx
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'CoQmx'] in either order.
# Leave out: 22DFx, Cr1sTi
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Cr1sTi'] in either order.
# Leave out: 22DFx, D9Hh9
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'D9Hh9'] in either order.
# Leave out: 22DFx, Dwf5T
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Dwf5T'] in either order.
# Leave out: 22DFx, EJOiBs
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'EJOiBs'] in either order.
# Leave out: 22DFx, ERqc8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'ERqc8'] in either order.
# Leave out: 22DFx, EXAMPLE
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'EXAMPLE'] in either order.
# Leave out: 22DFx, F5tXL
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'F5tXL'] in either order.
# Leave out: 22DFx, F8mDn
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'F8mDn'] in either order.
# Leave out: 22DFx, Fjil72
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Fjil72'] in either order.
# Leave out: 22DFx, Fk2oP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Fk2oP'] in either order.
# Leave out: 22DFx, G4Egk
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G4Egk'] in either order.
# Leave out: 22DFx, G4dLl
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G4dLl'] in either order.
# Leave out: 22DFx, G5XzoP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G5XzoP'] in either order.
# Leave out: 22DFx, GFGzP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'GFGzP'] in either order.
# Leave out: 22DFx, GHft8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'GHft8'] in either order.
# Leave out: 22DFx, Gax8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gax8'] in either order.
# Leave out: 22DFx, Gftw5
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gftw5'] in either order.
# Leave out: 22DFx, Gr33d
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gr33d'] in either order.
# Leave out: 22DFx, Hx7dO
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Hx7dO'] in either order.
# Leave out: 22DFx, KWgkc
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'KWgkc'] in either order.
# Leave out: 22DFx, Kgh4P3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Kgh4P3'] in either order.
# Leave out: 22DFx, KoG5ii
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'KoG5ii'] in either order.
# Leave out: 22DFx, LR96S
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'LR96S'] in either order.
# Leave out: 22DFx, M4t7k
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'M4t7k'] in either order.
# Leave out: 22DFx, NMy2s
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'NMy2s'] in either order.
# Leave out: 22DFx, O1pGR
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'O1pGR'] in either order.
# Leave out: 22DFx, PPjCX
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'PPjCX'] in either order.
# Leave out: 22DFx, Pi9803
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Pi9803'] in either order.
# Leave out: 22DFx, SI3pa2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'SI3pa2'] in either order.
# Leave out: 22DFx, V9D5x
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'V9D5x'] in either order.
# Leave out: 22DFx, WQzBV
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'WQzBV'] in either order.
# Leave out: 22DFx, WYuvqk
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'WYuvqk'] in either order.
# Leave out: 22DFx, XPI3pA
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'XPI3pA'] in either order.
# Leave out: 22DFx, Xd3foP9
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Xd3foP9'] in either order.
# Leave out: 22DFx, XhsN0o
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'XhsN0o'] in either order.
# Leave out: 22DFx, gf5X
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'gf5X'] in either order.
# Leave out: 22DFx, gjGzb
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'gjGzb'] in either order.
# Leave out: 22DFx, h2yD5h
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'h2yD5h'] in either order.
# Leave out: 22DFx, hMHEK1
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'hMHEK1'] in either order.
# Leave out: 22DFx, kH4Dd
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'kH4Dd'] in either order.
# Leave out: 22DFx, sop2d
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'sop2d'] in either order.
# Leave out: 22DFx, tMGNS
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'tMGNS'] in either order.
# Leave out: 22DFx, urJvc
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'urJvc'] in either order.
# Leave out: 22DFx, wohkw
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'wohkw'] in either order.
# Leave out: 22DFx, yb3T2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'yb3T2'] in either order.
# Leave out: 4FoNM, 22DFx
# [Warning] Ground truth file not found for participant pair ['4FoNM', '22DFx'] in either order.
# Leave out: 4FoNM, 5BJD3
# [Warning] Ground truth file not found for participant pair ['4FoNM', '5BJD3'] in either order.
# Leave out: 4FoNM, 5KB3V
# Leave out: 4FoNM, 6GSd4
# Leave out: 4FoNM, 7yqP3
# Leave out: 4FoNM, 9FGka
# [Warning] Ground truth file not found for participant pair ['4FoNM', '9FGka'] in either order.
# Leave out: 4FoNM, A5feTy
# Leave out: 4FoNM, Bs73
# Leave out: 4FoNM, CVgs2
# Leave out: 4FoNM, CoQmx
# Leave out: 4FoNM, Cr1sTi
# Leave out: 4FoNM, D9Hh9
# Leave out: 4FoNM, Dwf5T
# Leave out: 4FoNM, EJOiBs
# [Warning] Ground truth file not found for participant pair ['4FoNM', 'EJOiBs'] in either order.
# Leave out: 4FoNM, ERqc8
# Leave out: 4FoNM, EXAMPLE
# Leave out: 4FoNM, F5tXL
# Leave out: 4FoNM, F8mDn
# Leave out: 4FoNM, Fjil72
# Leave out: 4FoNM, Fk2oP
# [Warning] Ground truth file not found for participant pair ['4FoNM', 'Fk2oP'] in either order.
# Leave out: 4FoNM, G4Egk
# Leave out: 4FoNM, G4dLl
# Leave out: 4FoNM, G5XzoP
# Leave out: 4FoNM, GFGzP
# Leave out: 4FoNM, GHft8
# Leave out: 4FoNM, Gax8
# Leave out: 4FoNM, Gftw5
# Leave out: 4FoNM, Gr33d
# Leave out: 4FoNM, Hx7dO
# Leave out: 4FoNM, KWgkc
# Leave out: 4FoNM, Kgh4P3
# Leave out: 4FoNM, KoG5ii
# Leave out: 4FoNM, LR96S
# Leave out: 4FoNM, M4t7k
# Leave out: 4FoNM, NMy2s
# Leave out: 4FoNM, O1pGR
# Leave out: 4FoNM, PPjCX
# Leave out: 4FoNM, Pi9803
# Leave out: 4FoNM, SI3pa2
# Leave out: 4FoNM, V9D5x
# Leave out: 4FoNM, WQzBV
# Leave out: 4FoNM, WYuvqk
# Leave out: 4FoNM, XPI3pA
# Leave out: 4FoNM, Xd3foP9
# Leave out: 4FoNM, XhsN0o
# Leave out: 4FoNM, gf5X
# Leave out: 4FoNM, gjGzb
# Leave out: 4FoNM, h2yD5h
# Leave out: 4FoNM, hMHEK1
# Leave out: 4FoNM, kH4Dd
# Leave out: 4FoNM, sop2d
# Leave out: 4FoNM, tMGNS
# Leave out: 4FoNM, urJvc
# Leave out: 4FoNM, wohkw
# Leave out: 4FoNM, yb3T2
# Leave out: 5BJD3, 22DFx
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '22DFx'] in either order.
# Leave out: 5BJD3, 4FoNM
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '4FoNM'] in either order.
# Leave out: 5BJD3, 5KB3V
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '5KB3V'] in either order.
# Leave out: 5BJD3, 6GSd4
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '6GSd4'] in either order.
# Leave out: 5BJD3, 7yqP3
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '7yqP3'] in either order.
# Leave out: 5BJD3, 9FGka
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '9FGka'] in either order.
# Leave out: 5BJD3, A5feTy
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'A5feTy'] in either order.
# Leave out: 5BJD3, Bs73
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Bs73'] in either order.
# Leave out: 5BJD3, CVgs2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'CVgs2'] in either order.
# Leave out: 5BJD3, CoQmx
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'CoQmx'] in either order.
# Leave out: 5BJD3, Cr1sTi
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Cr1sTi'] in either order.
# Leave out: 5BJD3, D9Hh9
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'D9Hh9'] in either order.
# Leave out: 5BJD3, Dwf5T
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Dwf5T'] in either order.
# Leave out: 5BJD3, EJOiBs
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'EJOiBs'] in either order.
# Leave out: 5BJD3, ERqc8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'ERqc8'] in either order.
# Leave out: 5BJD3, EXAMPLE
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'EXAMPLE'] in either order.
# Leave out: 5BJD3, F5tXL
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'F5tXL'] in either order.
# Leave out: 5BJD3, F8mDn
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'F8mDn'] in either order.
# Leave out: 5BJD3, Fjil72
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Fjil72'] in either order.
# Leave out: 5BJD3, Fk2oP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Fk2oP'] in either order.
# Leave out: 5BJD3, G4Egk
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G4Egk'] in either order.
# Leave out: 5BJD3, G4dLl
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G4dLl'] in either order.
# Leave out: 5BJD3, G5XzoP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G5XzoP'] in either order.
# Leave out: 5BJD3, GFGzP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'GFGzP'] in either order.
# Leave out: 5BJD3, GHft8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'GHft8'] in either order.
# Leave out: 5BJD3, Gax8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gax8'] in either order.
# Leave out: 5BJD3, Gftw5
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gftw5'] in either order.
# Leave out: 5BJD3, Gr33d
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gr33d'] in either order.
# Leave out: 5BJD3, Hx7dO
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Hx7dO'] in either order.
# Leave out: 5BJD3, KWgkc
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'KWgkc'] in either order.
# Leave out: 5BJD3, Kgh4P3
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Kgh4P3'] in either order.
# Leave out: 5BJD3, KoG5ii
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'KoG5ii'] in either order.
# Leave out: 5BJD3, LR96S
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'LR96S'] in either order.
# Leave out: 5BJD3, M4t7k
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'M4t7k'] in either order.
# Leave out: 5BJD3, NMy2s
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'NMy2s'] in either order.
# Leave out: 5BJD3, O1pGR
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'O1pGR'] in either order.
# Leave out: 5BJD3, PPjCX
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'PPjCX'] in either order.
# Leave out: 5BJD3, Pi9803
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Pi9803'] in either order.
# Leave out: 5BJD3, SI3pa2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'SI3pa2'] in either order.
# Leave out: 5BJD3, V9D5x
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'V9D5x'] in either order.
# Leave out: 5BJD3, WQzBV
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'WQzBV'] in either order.
# Leave out: 5BJD3, WYuvqk
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'WYuvqk'] in either order.
# Leave out: 5BJD3, XPI3pA
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'XPI3pA'] in either order.
# Leave out: 5BJD3, Xd3foP9
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Xd3foP9'] in either order.
# Leave out: 5BJD3, XhsN0o
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'XhsN0o'] in either order.
# Leave out: 5BJD3, gf5X
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'gf5X'] in either order.
# Leave out: 5BJD3, gjGzb
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'gjGzb'] in either order.
# Leave out: 5BJD3, h2yD5h
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'h2yD5h'] in either order.
# Leave out: 5BJD3, hMHEK1
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'hMHEK1'] in either order.
# Leave out: 5BJD3, kH4Dd
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'kH4Dd'] in either order.
# Leave out: 5BJD3, sop2d
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'sop2d'] in either order.
# Leave out: 5BJD3, tMGNS
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'tMGNS'] in either order.
# Leave out: 5BJD3, urJvc
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'urJvc'] in either order.
# Leave out: 5BJD3, wohkw
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'wohkw'] in either order.
# Leave out: 5BJD3, yb3T2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'yb3T2'] in either order.
# Leave out: 5KB3V, 22DFx
# [Warning] Ground truth file not found for participant pair ['5KB3V', '22DFx'] in either order.
# Leave out: 5KB3V, 4FoNM
# Leave out: 5KB3V, 5BJD3
# [Warning] Ground truth file not found for participant pair ['5KB3V', '5BJD3'] in either order.
# Leave out: 5KB3V, 6GSd4
# Leave out: 5KB3V, 7yqP3
# Leave out: 5KB3V, 9FGka
# [Warning] Ground truth file not found for participant pair ['5KB3V', '9FGka'] in either order.
# Leave out: 5KB3V, A5feTy
# Leave out: 5KB3V, Bs73
# Leave out: 5KB3V, CVgs2
# Leave out: 5KB3V, CoQmx
# Leave out: 5KB3V, Cr1sTi
# Leave out: 5KB3V, D9Hh9
# Leave out: 5KB3V, Dwf5T
# Leave out: 5KB3V, EJOiBs
# [Warning] Ground truth file not found for participant pair ['5KB3V', 'EJOiBs'] in either order.
# Leave out: 5KB3V, ERqc8
# Leave out: 5KB3V, EXAMPLE
# Leave out: 5KB3V, F5tXL
# Leave out: 5KB3V, F8mDn
# Leave out: 5KB3V, Fjil72
# Leave out: 5KB3V, Fk2oP
# [Warning] Ground truth file not found for participant pair ['5KB3V', 'Fk2oP'] in either order.
# Leave out: 5KB3V, G4Egk
# Leave out: 5KB3V, G4dLl
# Leave out: 5KB3V, G5XzoP
# Leave out: 5KB3V, GFGzP
# Leave out: 5KB3V, GHft8
# Leave out: 5KB3V, Gax8
# Leave out: 5KB3V, Gftw5
# Leave out: 5KB3V, Gr33d
# Leave out: 5KB3V, Hx7dO
# Leave out: 5KB3V, KWgkc
# Leave out: 5KB3V, Kgh4P3
# Leave out: 5KB3V, KoG5ii
# Leave out: 5KB3V, LR96S
# Leave out: 5KB3V, M4t7k
# Leave out: 5KB3V, NMy2s
# Leave out: 5KB3V, O1pGR
# Leave out: 5KB3V, PPjCX
# Leave out: 5KB3V, Pi9803
# Leave out: 5KB3V, SI3pa2
# Leave out: 5KB3V, V9D5x
# Leave out: 5KB3V, WQzBV
# Leave out: 5KB3V, WYuvqk
# Leave out: 5KB3V, XPI3pA
# Leave out: 5KB3V, Xd3foP9
# Leave out: 5KB3V, XhsN0o
# Leave out: 5KB3V, gf5X
# Leave out: 5KB3V, gjGzb
# Leave out: 5KB3V, h2yD5h
# Leave out: 5KB3V, hMHEK1
# Leave out: 5KB3V, kH4Dd
# Leave out: 5KB3V, sop2d
# Leave out: 5KB3V, tMGNS
# Leave out: 5KB3V, urJvc
# Leave out: 5KB3V, wohkw
# Leave out: 5KB3V, yb3T2
# Leave out: 6GSd4, 22DFx
# [Warning] Ground truth file not found for participant pair ['6GSd4', '22DFx'] in either order.
# Leave out: 6GSd4, 4FoNM
# Leave out: 6GSd4, 5BJD3
# [Warning] Ground truth file not found for participant pair ['6GSd4', '5BJD3'] in either order.
# Leave out: 6GSd4, 5KB3V
# Leave out: 6GSd4, 7yqP3
# Leave out: 6GSd4, 9FGka
# [Warning] Ground truth file not found for participant pair ['6GSd4', '9FGka'] in either order.
# Leave out: 6GSd4, A5feTy
# Leave out: 6GSd4, Bs73
# Leave out: 6GSd4, CVgs2
# Leave out: 6GSd4, CoQmx
# Leave out: 6GSd4, Cr1sTi
# Leave out: 6GSd4, D9Hh9
# Leave out: 6GSd4, Dwf5T
# Leave out: 6GSd4, EJOiBs
# [Warning] Ground truth file not found for participant pair ['6GSd4', 'EJOiBs'] in either order.
# Leave out: 6GSd4, ERqc8
# Leave out: 6GSd4, EXAMPLE
# Leave out: 6GSd4, F5tXL
# Leave out: 6GSd4, F8mDn
# Leave out: 6GSd4, Fjil72
# Leave out: 6GSd4, Fk2oP
# [Warning] Ground truth file not found for participant pair ['6GSd4', 'Fk2oP'] in either order.
# Leave out: 6GSd4, G4Egk
# Leave out: 6GSd4, G4dLl
# Leave out: 6GSd4, G5XzoP
# Leave out: 6GSd4, GFGzP
# Leave out: 6GSd4, GHft8
# Leave out: 6GSd4, Gax8
# Leave out: 6GSd4, Gftw5
# Leave out: 6GSd4, Gr33d
# Leave out: 6GSd4, Hx7dO
# Leave out: 6GSd4, KWgkc
# Leave out: 6GSd4, Kgh4P3
# Leave out: 6GSd4, KoG5ii
# Leave out: 6GSd4, LR96S
# Leave out: 6GSd4, M4t7k
# Leave out: 6GSd4, NMy2s
# Leave out: 6GSd4, O1pGR
# Leave out: 6GSd4, PPjCX
# Leave out: 6GSd4, Pi9803
# Leave out: 6GSd4, SI3pa2
# Leave out: 6GSd4, V9D5x
# Leave out: 6GSd4, WQzBV
# Leave out: 6GSd4, WYuvqk
# Leave out: 6GSd4, XPI3pA
# Leave out: 6GSd4, Xd3foP9
# Leave out: 6GSd4, XhsN0o
# Leave out: 6GSd4, gf5X
# Leave out: 6GSd4, gjGzb
# Leave out: 6GSd4, h2yD5h
# Leave out: 6GSd4, hMHEK1
# Leave out: 6GSd4, kH4Dd
# Leave out: 6GSd4, sop2d
# Leave out: 6GSd4, tMGNS
# Leave out: 6GSd4, urJvc
# Leave out: 6GSd4, wohkw
# Leave out: 6GSd4, yb3T2
# Leave out: 7yqP3, 22DFx
# [Warning] Ground truth file not found for participant pair ['7yqP3', '22DFx'] in either order.
# Leave out: 7yqP3, 4FoNM
# Leave out: 7yqP3, 5BJD3
# [Warning] Ground truth file not found for participant pair ['7yqP3', '5BJD3'] in either order.
# Leave out: 7yqP3, 5KB3V
# Leave out: 7yqP3, 6GSd4
# Leave out: 7yqP3, 9FGka
# [Warning] Ground truth file not found for participant pair ['7yqP3', '9FGka'] in either order.
# Leave out: 7yqP3, A5feTy
# Leave out: 7yqP3, Bs73
# Leave out: 7yqP3, CVgs2
# Leave out: 7yqP3, CoQmx
# Leave out: 7yqP3, Cr1sTi
# Leave out: 7yqP3, D9Hh9
# Leave out: 7yqP3, Dwf5T
# Leave out: 7yqP3, EJOiBs
# [Warning] Ground truth file not found for participant pair ['7yqP3', 'EJOiBs'] in either order.
# Leave out: 7yqP3, ERqc8
# Leave out: 7yqP3, EXAMPLE
# Leave out: 7yqP3, F5tXL
# Leave out: 7yqP3, F8mDn
# Leave out: 7yqP3, Fjil72
# Leave out: 7yqP3, Fk2oP
# [Warning] Ground truth file not found for participant pair ['7yqP3', 'Fk2oP'] in either order.
# Leave out: 7yqP3, G4Egk
# Leave out: 7yqP3, G4dLl
# Leave out: 7yqP3, G5XzoP
# Leave out: 7yqP3, GFGzP
# Leave out: 7yqP3, GHft8
# Leave out: 7yqP3, Gax8
# Leave out: 7yqP3, Gftw5
# Leave out: 7yqP3, Gr33d
# Leave out: 7yqP3, Hx7dO
# Leave out: 7yqP3, KWgkc
# Leave out: 7yqP3, Kgh4P3
# Leave out: 7yqP3, KoG5ii
# Leave out: 7yqP3, LR96S
# Leave out: 7yqP3, M4t7k
# Leave out: 7yqP3, NMy2s
# Leave out: 7yqP3, O1pGR
# Leave out: 7yqP3, PPjCX
# Leave out: 7yqP3, Pi9803
# Leave out: 7yqP3, SI3pa2
# Leave out: 7yqP3, V9D5x
# Leave out: 7yqP3, WQzBV
# Leave out: 7yqP3, WYuvqk
# Leave out: 7yqP3, XPI3pA
# Leave out: 7yqP3, Xd3foP9
# Leave out: 7yqP3, XhsN0o
# Leave out: 7yqP3, gf5X
# Leave out: 7yqP3, gjGzb
# Leave out: 7yqP3, h2yD5h
# Leave out: 7yqP3, hMHEK1
# Leave out: 7yqP3, kH4Dd
# Leave out: 7yqP3, sop2d
# Leave out: 7yqP3, tMGNS
# Leave out: 7yqP3, urJvc
# Leave out: 7yqP3, wohkw
# Leave out: 7yqP3, yb3T2
# Leave out: 9FGka, 22DFx
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '22DFx'] in either order.
# Leave out: 9FGka, 4FoNM
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '4FoNM'] in either order.
# Leave out: 9FGka, 5BJD3
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '5BJD3'] in either order.
# Leave out: 9FGka, 5KB3V
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '5KB3V'] in either order.
# Leave out: 9FGka, 6GSd4
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '6GSd4'] in either order.
# Leave out: 9FGka, 7yqP3
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '7yqP3'] in either order.
# Leave out: 9FGka, A5feTy
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'A5feTy'] in either order.
# Leave out: 9FGka, Bs73
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Bs73'] in either order.
# Leave out: 9FGka, CVgs2
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'CVgs2'] in either order.
# Leave out: 9FGka, CoQmx
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'CoQmx'] in either order.
# Leave out: 9FGka, Cr1sTi
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Cr1sTi'] in either order.
# Leave out: 9FGka, D9Hh9
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'D9Hh9'] in either order.
# Leave out: 9FGka, Dwf5T
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Dwf5T'] in either order.
# Leave out: 9FGka, EJOiBs
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'EJOiBs'] in either order.
# Leave out: 9FGka, ERqc8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'ERqc8'] in either order.
# Leave out: 9FGka, EXAMPLE
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'EXAMPLE'] in either order.
# Leave out: 9FGka, F5tXL
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'F5tXL'] in either order.
# Leave out: 9FGka, F8mDn
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'F8mDn'] in either order.
# Leave out: 9FGka, Fjil72
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Fjil72'] in either order.
# Leave out: 9FGka, Fk2oP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Fk2oP'] in either order.
# Leave out: 9FGka, G4Egk
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G4Egk'] in either order.
# Leave out: 9FGka, G4dLl
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G4dLl'] in either order.
# Leave out: 9FGka, G5XzoP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G5XzoP'] in either order.
# Leave out: 9FGka, GFGzP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'GFGzP'] in either order.
# Leave out: 9FGka, GHft8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'GHft8'] in either order.
# Leave out: 9FGka, Gax8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Gax8'] in either order.
# ...
# Leave out: gjGzb, PPjCX
# Leave out: gjGzb, Pi9803
# Leave out: gjGzb, SI3pa2
# Leave out: gjGzb, V9D5x
# Leave out: gjGzb, WQzBV
# Leave out: gjGzb, WYuvqk
# Leave out: gjGzb, XPI3pA
# Leave out: gjGzb, Xd3foP9
# Leave out: gjGzb, XhsN0o
# Leave out: gjGzb, gf5X
# Leave out: gjGzb, h2yD5h
# Leave out: gjGzb, hMHEK1
# Leave out: gjGzb, kH4Dd
# Leave out: gjGzb, sop2d
# Leave out: gjGzb, tMGNS
# Leave out: gjGzb, urJvc
# Leave out: gjGzb, wohkw
# Leave out: gjGzb, yb3T2
# Leave out: h2yD5h, 22DFx
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '22DFx'] in either order.
# Leave out: h2yD5h, 4FoNM
# Leave out: h2yD5h, 5BJD3
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '5BJD3'] in either order.
# Leave out: h2yD5h, 5KB3V
# Leave out: h2yD5h, 6GSd4
# Leave out: h2yD5h, 7yqP3
# Leave out: h2yD5h, 9FGka
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '9FGka'] in either order.
# Leave out: h2yD5h, A5feTy
# Leave out: h2yD5h, Bs73
# Leave out: h2yD5h, CVgs2
# Leave out: h2yD5h, CoQmx
# Leave out: h2yD5h, Cr1sTi
# Leave out: h2yD5h, D9Hh9
# Leave out: h2yD5h, Dwf5T
# Leave out: h2yD5h, EJOiBs
# [Warning] Ground truth file not found for participant pair ['h2yD5h', 'EJOiBs'] in either order.
# Leave out: h2yD5h, ERqc8
# Leave out: h2yD5h, EXAMPLE
# Leave out: h2yD5h, F5tXL
# Leave out: h2yD5h, F8mDn
# Leave out: h2yD5h, Fjil72
# Leave out: h2yD5h, Fk2oP
# [Warning] Ground truth file not found for participant pair ['h2yD5h', 'Fk2oP'] in either order.
# Leave out: h2yD5h, G4Egk
# Leave out: h2yD5h, G4dLl
# Leave out: h2yD5h, G5XzoP
# Leave out: h2yD5h, GFGzP
# Leave out: h2yD5h, GHft8
# Leave out: h2yD5h, Gax8
# Leave out: h2yD5h, Gftw5
# Leave out: h2yD5h, Gr33d
# Leave out: h2yD5h, Hx7dO
# Leave out: h2yD5h, KWgkc
# Leave out: h2yD5h, Kgh4P3
# Leave out: h2yD5h, KoG5ii
# Leave out: h2yD5h, LR96S
# Leave out: h2yD5h, M4t7k
# Leave out: h2yD5h, NMy2s
# Leave out: h2yD5h, O1pGR
# Leave out: h2yD5h, PPjCX
# Leave out: h2yD5h, Pi9803
# Leave out: h2yD5h, SI3pa2
# Leave out: h2yD5h, V9D5x
# Leave out: h2yD5h, WQzBV
# Leave out: h2yD5h, WYuvqk
# Leave out: h2yD5h, XPI3pA
# Leave out: h2yD5h, Xd3foP9
# Leave out: h2yD5h, XhsN0o
# Leave out: h2yD5h, gf5X
# Leave out: h2yD5h, gjGzb
# Leave out: h2yD5h, hMHEK1
# Leave out: h2yD5h, kH4Dd
# Leave out: h2yD5h, sop2d
# Leave out: h2yD5h, tMGNS
# Leave out: h2yD5h, urJvc
# Leave out: h2yD5h, wohkw
# Leave out: h2yD5h, yb3T2
# Leave out: hMHEK1, 22DFx
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '22DFx'] in either order.
# Leave out: hMHEK1, 4FoNM
# Leave out: hMHEK1, 5BJD3
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '5BJD3'] in either order.
# Leave out: hMHEK1, 5KB3V
# Leave out: hMHEK1, 6GSd4
# Leave out: hMHEK1, 7yqP3
# Leave out: hMHEK1, 9FGka
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '9FGka'] in either order.
# Leave out: hMHEK1, A5feTy
# Leave out: hMHEK1, Bs73
# Leave out: hMHEK1, CVgs2
# Leave out: hMHEK1, CoQmx
# Leave out: hMHEK1, Cr1sTi
# Leave out: hMHEK1, D9Hh9
# Leave out: hMHEK1, Dwf5T
# Leave out: hMHEK1, EJOiBs
# [Warning] Ground truth file not found for participant pair ['hMHEK1', 'EJOiBs'] in either order.
# Leave out: hMHEK1, ERqc8
# Leave out: hMHEK1, EXAMPLE
# Leave out: hMHEK1, F5tXL
# Leave out: hMHEK1, F8mDn
# Leave out: hMHEK1, Fjil72
# Leave out: hMHEK1, Fk2oP
# [Warning] Ground truth file not found for participant pair ['hMHEK1', 'Fk2oP'] in either order.
# Leave out: hMHEK1, G4Egk
# Leave out: hMHEK1, G4dLl
# Leave out: hMHEK1, G5XzoP
# Leave out: hMHEK1, GFGzP
# Leave out: hMHEK1, GHft8
# Leave out: hMHEK1, Gax8
# Leave out: hMHEK1, Gftw5
# Leave out: hMHEK1, Gr33d
# Leave out: hMHEK1, Hx7dO
# Leave out: hMHEK1, KWgkc
# Leave out: hMHEK1, Kgh4P3
# Leave out: hMHEK1, KoG5ii
# Leave out: hMHEK1, LR96S
# Leave out: hMHEK1, M4t7k
# Leave out: hMHEK1, NMy2s
# Leave out: hMHEK1, O1pGR
# Leave out: hMHEK1, PPjCX
# Leave out: hMHEK1, Pi9803
# Leave out: hMHEK1, SI3pa2
# Leave out: hMHEK1, V9D5x
# Leave out: hMHEK1, WQzBV
# Leave out: hMHEK1, WYuvqk
# Leave out: hMHEK1, XPI3pA
# Leave out: hMHEK1, Xd3foP9
# Leave out: hMHEK1, XhsN0o
# Leave out: hMHEK1, gf5X
# Leave out: hMHEK1, gjGzb
# Leave out: hMHEK1, h2yD5h
# Leave out: hMHEK1, kH4Dd
# Leave out: hMHEK1, sop2d
# Leave out: hMHEK1, tMGNS
# Leave out: hMHEK1, urJvc
# Leave out: hMHEK1, wohkw
# Leave out: hMHEK1, yb3T2
# Leave out: kH4Dd, 22DFx
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '22DFx'] in either order.
# Leave out: kH4Dd, 4FoNM
# Leave out: kH4Dd, 5BJD3
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '5BJD3'] in either order.
# Leave out: kH4Dd, 5KB3V
# Leave out: kH4Dd, 6GSd4
# Leave out: kH4Dd, 7yqP3
# Leave out: kH4Dd, 9FGka
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '9FGka'] in either order.
# Leave out: kH4Dd, A5feTy
# Leave out: kH4Dd, Bs73
# Leave out: kH4Dd, CVgs2
# Leave out: kH4Dd, CoQmx
# Leave out: kH4Dd, Cr1sTi
# Leave out: kH4Dd, D9Hh9
# Leave out: kH4Dd, Dwf5T
# Leave out: kH4Dd, EJOiBs
# [Warning] Ground truth file not found for participant pair ['kH4Dd', 'EJOiBs'] in either order.
# Leave out: kH4Dd, ERqc8
# Leave out: kH4Dd, EXAMPLE
# Leave out: kH4Dd, F5tXL
# Leave out: kH4Dd, F8mDn
# Leave out: kH4Dd, Fjil72
# Leave out: kH4Dd, Fk2oP
# [Warning] Ground truth file not found for participant pair ['kH4Dd', 'Fk2oP'] in either order.
# Leave out: kH4Dd, G4Egk
# Leave out: kH4Dd, G4dLl
# Leave out: kH4Dd, G5XzoP
# Leave out: kH4Dd, GFGzP
# Leave out: kH4Dd, GHft8
# Leave out: kH4Dd, Gax8
# Leave out: kH4Dd, Gftw5
# Leave out: kH4Dd, Gr33d
# Leave out: kH4Dd, Hx7dO
# Leave out: kH4Dd, KWgkc
# Leave out: kH4Dd, Kgh4P3
# Leave out: kH4Dd, KoG5ii
# Leave out: kH4Dd, LR96S
# Leave out: kH4Dd, M4t7k
# Leave out: kH4Dd, NMy2s
# Leave out: kH4Dd, O1pGR
# Leave out: kH4Dd, PPjCX
# Leave out: kH4Dd, Pi9803
# Leave out: kH4Dd, SI3pa2
# Leave out: kH4Dd, V9D5x
# Leave out: kH4Dd, WQzBV
# Leave out: kH4Dd, WYuvqk
# Leave out: kH4Dd, XPI3pA
# Leave out: kH4Dd, Xd3foP9
# Leave out: kH4Dd, XhsN0o
# Leave out: kH4Dd, gf5X
# Leave out: kH4Dd, gjGzb
# Leave out: kH4Dd, h2yD5h
# Leave out: kH4Dd, hMHEK1
# Leave out: kH4Dd, sop2d
# Leave out: kH4Dd, tMGNS
# Leave out: kH4Dd, urJvc
# Leave out: kH4Dd, wohkw
# Leave out: kH4Dd, yb3T2
# Leave out: sop2d, 22DFx
# [Warning] Ground truth file not found for participant pair ['sop2d', '22DFx'] in either order.
# Leave out: sop2d, 4FoNM
# Leave out: sop2d, 5BJD3
# [Warning] Ground truth file not found for participant pair ['sop2d', '5BJD3'] in either order.
# Leave out: sop2d, 5KB3V
# Leave out: sop2d, 6GSd4
# Leave out: sop2d, 7yqP3
# Leave out: sop2d, 9FGka
# [Warning] Ground truth file not found for participant pair ['sop2d', '9FGka'] in either order.
# Leave out: sop2d, A5feTy
# Leave out: sop2d, Bs73
# Leave out: sop2d, CVgs2
# Leave out: sop2d, CoQmx
# Leave out: sop2d, Cr1sTi
# Leave out: sop2d, D9Hh9
# Leave out: sop2d, Dwf5T
# Leave out: sop2d, EJOiBs
# [Warning] Ground truth file not found for participant pair ['sop2d', 'EJOiBs'] in either order.
# Leave out: sop2d, ERqc8
# Leave out: sop2d, EXAMPLE
# Leave out: sop2d, F5tXL
# Leave out: sop2d, F8mDn
# Leave out: sop2d, Fjil72
# Leave out: sop2d, Fk2oP
# [Warning] Ground truth file not found for participant pair ['sop2d', 'Fk2oP'] in either order.
# Leave out: sop2d, G4Egk
# Leave out: sop2d, G4dLl
# Leave out: sop2d, G5XzoP
# Leave out: sop2d, GFGzP
# Leave out: sop2d, GHft8
# Leave out: sop2d, Gax8
# Leave out: sop2d, Gftw5
# Leave out: sop2d, Gr33d
# Leave out: sop2d, Hx7dO
# Leave out: sop2d, KWgkc
# Leave out: sop2d, Kgh4P3
# Leave out: sop2d, KoG5ii
# Leave out: sop2d, LR96S
# Leave out: sop2d, M4t7k
# Leave out: sop2d, NMy2s
# Leave out: sop2d, O1pGR
# Leave out: sop2d, PPjCX
# Leave out: sop2d, Pi9803
# Leave out: sop2d, SI3pa2
# Leave out: sop2d, V9D5x
# Leave out: sop2d, WQzBV
# Leave out: sop2d, WYuvqk
# Leave out: sop2d, XPI3pA
# Leave out: sop2d, Xd3foP9
# Leave out: sop2d, XhsN0o
# Leave out: sop2d, gf5X
# Leave out: sop2d, gjGzb
# Leave out: sop2d, h2yD5h
# Leave out: sop2d, hMHEK1
# Leave out: sop2d, kH4Dd
# Leave out: sop2d, tMGNS
# Leave out: sop2d, urJvc
# Leave out: sop2d, wohkw
# Leave out: sop2d, yb3T2
# Leave out: tMGNS, 22DFx
# [Warning] Ground truth file not found for participant pair ['tMGNS', '22DFx'] in either order.
# Leave out: tMGNS, 4FoNM
# Leave out: tMGNS, 5BJD3
# [Warning] Ground truth file not found for participant pair ['tMGNS', '5BJD3'] in either order.
# Leave out: tMGNS, 5KB3V
# Leave out: tMGNS, 6GSd4
# Leave out: tMGNS, 7yqP3
# Leave out: tMGNS, 9FGka
# [Warning] Ground truth file not found for participant pair ['tMGNS', '9FGka'] in either order.
# Leave out: tMGNS, A5feTy
# Leave out: tMGNS, Bs73
# Leave out: tMGNS, CVgs2
# Leave out: tMGNS, CoQmx
# Leave out: tMGNS, Cr1sTi
# Leave out: tMGNS, D9Hh9
# Leave out: tMGNS, Dwf5T
# Leave out: tMGNS, EJOiBs
# [Warning] Ground truth file not found for participant pair ['tMGNS', 'EJOiBs'] in either order.
# Leave out: tMGNS, ERqc8
# Leave out: tMGNS, EXAMPLE
# Leave out: tMGNS, F5tXL
# Leave out: tMGNS, F8mDn
# Leave out: tMGNS, Fjil72
# Leave out: tMGNS, Fk2oP
# [Warning] Ground truth file not found for participant pair ['tMGNS', 'Fk2oP'] in either order.
# Leave out: tMGNS, G4Egk
# Leave out: tMGNS, G4dLl
# Leave out: tMGNS, G5XzoP
# Leave out: tMGNS, GFGzP
# Leave out: tMGNS, GHft8
# Leave out: tMGNS, Gax8
# Leave out: tMGNS, Gftw5
# Leave out: tMGNS, Gr33d
# Leave out: tMGNS, Hx7dO
# Leave out: tMGNS, KWgkc
# Leave out: tMGNS, Kgh4P3
# Leave out: tMGNS, KoG5ii
# Leave out: tMGNS, LR96S
# Leave out: tMGNS, M4t7k
# Leave out: tMGNS, NMy2s
# Leave out: tMGNS, O1pGR
# Leave out: tMGNS, PPjCX
# Leave out: tMGNS, Pi9803
# Leave out: tMGNS, SI3pa2
# Leave out: tMGNS, V9D5x
# Leave out: tMGNS, WQzBV
# Leave out: tMGNS, WYuvqk
# Leave out: tMGNS, XPI3pA
# Leave out: tMGNS, Xd3foP9
# Leave out: tMGNS, XhsN0o
# Leave out: tMGNS, gf5X
# Leave out: tMGNS, gjGzb
# Leave out: tMGNS, h2yD5h
# Leave out: tMGNS, hMHEK1
# Leave out: tMGNS, kH4Dd
# Leave out: tMGNS, sop2d
# Leave out: tMGNS, urJvc
# Leave out: tMGNS, wohkw
# Leave out: tMGNS, yb3T2
# Leave out: urJvc, 22DFx
# [Warning] Ground truth file not found for participant pair ['urJvc', '22DFx'] in either order.
# Leave out: urJvc, 4FoNM
# Leave out: urJvc, 5BJD3
# [Warning] Ground truth file not found for participant pair ['urJvc', '5BJD3'] in either order.
# Leave out: urJvc, 5KB3V
# Leave out: urJvc, 6GSd4
# Leave out: urJvc, 7yqP3
# Leave out: urJvc, 9FGka
# [Warning] Ground truth file not found for participant pair ['urJvc', '9FGka'] in either order.
# Leave out: urJvc, A5feTy
# Leave out: urJvc, Bs73
# Leave out: urJvc, CVgs2
# Leave out: urJvc, CoQmx
# Leave out: urJvc, Cr1sTi
# Leave out: urJvc, D9Hh9
# Leave out: urJvc, Dwf5T
# Leave out: urJvc, EJOiBs
# [Warning] Ground truth file not found for participant pair ['urJvc', 'EJOiBs'] in either order.
# Leave out: urJvc, ERqc8
# Leave out: urJvc, EXAMPLE
# Leave out: urJvc, F5tXL
# Leave out: urJvc, F8mDn
# Leave out: urJvc, Fjil72
# Leave out: urJvc, Fk2oP
# [Warning] Ground truth file not found for participant pair ['urJvc', 'Fk2oP'] in either order.
# Leave out: urJvc, G4Egk
# Leave out: urJvc, G4dLl
# Leave out: urJvc, G5XzoP
# Leave out: urJvc, GFGzP
# Leave out: urJvc, GHft8
# Leave out: urJvc, Gax8
# Leave out: urJvc, Gftw5
# Leave out: urJvc, Gr33d
# Leave out: urJvc, Hx7dO
# Leave out: urJvc, KWgkc
# Leave out: urJvc, Kgh4P3
# Leave out: urJvc, KoG5ii
# Leave out: urJvc, LR96S
# Leave out: urJvc, M4t7k
# Leave out: urJvc, NMy2s
# Leave out: urJvc, O1pGR
# Leave out: urJvc, PPjCX
# Leave out: urJvc, Pi9803
# Leave out: urJvc, SI3pa2
# Leave out: urJvc, V9D5x
# Leave out: urJvc, WQzBV
# Leave out: urJvc, WYuvqk
# Leave out: urJvc, XPI3pA
# Leave out: urJvc, Xd3foP9
# Leave out: urJvc, XhsN0o
# Leave out: urJvc, gf5X
# Leave out: urJvc, gjGzb
# Leave out: urJvc, h2yD5h
# Leave out: urJvc, hMHEK1
# Leave out: urJvc, kH4Dd
# Leave out: urJvc, sop2d
# Leave out: urJvc, tMGNS
# Leave out: urJvc, wohkw
# Leave out: urJvc, yb3T2
# Leave out: wohkw, 22DFx
# [Warning] Ground truth file not found for participant pair ['wohkw', '22DFx'] in either order.
# Leave out: wohkw, 4FoNM
# Leave out: wohkw, 5BJD3
# [Warning] Ground truth file not found for participant pair ['wohkw', '5BJD3'] in either order.
# Leave out: wohkw, 5KB3V
# Leave out: wohkw, 6GSd4
# Leave out: wohkw, 7yqP3
# Leave out: wohkw, 9FGka
# [Warning] Ground truth file not found for participant pair ['wohkw', '9FGka'] in either order.
# Leave out: wohkw, A5feTy
# Leave out: wohkw, Bs73
# Leave out: wohkw, CVgs2
# Leave out: wohkw, CoQmx
# Leave out: wohkw, Cr1sTi
# Leave out: wohkw, D9Hh9
# Leave out: wohkw, Dwf5T
# Leave out: wohkw, EJOiBs
# [Warning] Ground truth file not found for participant pair ['wohkw', 'EJOiBs'] in either order.
# Leave out: wohkw, ERqc8
# Leave out: wohkw, EXAMPLE
# Leave out: wohkw, F5tXL
# Leave out: wohkw, F8mDn
# Leave out: wohkw, Fjil72
# Leave out: wohkw, Fk2oP
# [Warning] Ground truth file not found for participant pair ['wohkw', 'Fk2oP'] in either order.
# Leave out: wohkw, G4Egk
# Leave out: wohkw, G4dLl
# Leave out: wohkw, G5XzoP
# Leave out: wohkw, GFGzP
# Leave out: wohkw, GHft8
# Leave out: wohkw, Gax8
# Leave out: wohkw, Gftw5
# Leave out: wohkw, Gr33d
# Leave out: wohkw, Hx7dO
# Leave out: wohkw, KWgkc
# Leave out: wohkw, Kgh4P3
# Leave out: wohkw, KoG5ii
# Leave out: wohkw, LR96S
# Leave out: wohkw, M4t7k
# Leave out: wohkw, NMy2s
# Leave out: wohkw, O1pGR
# Leave out: wohkw, PPjCX
# Leave out: wohkw, Pi9803
# Leave out: wohkw, SI3pa2
# Leave out: wohkw, V9D5x
# Leave out: wohkw, WQzBV
# Leave out: wohkw, WYuvqk
# Leave out: wohkw, XPI3pA
# Leave out: wohkw, Xd3foP9
# Leave out: wohkw, XhsN0o
# Leave out: wohkw, gf5X
# Leave out: wohkw, gjGzb
# Leave out: wohkw, h2yD5h
# Leave out: wohkw, hMHEK1
# Leave out: wohkw, kH4Dd
# Leave out: wohkw, sop2d
# Leave out: wohkw, tMGNS
# Leave out: wohkw, urJvc
# Leave out: wohkw, yb3T2
# Leave out: yb3T2, 22DFx
# [Warning] Ground truth file not found for participant pair ['yb3T2', '22DFx'] in either order.
# Leave out: yb3T2, 4FoNM
# Leave out: yb3T2, 5BJD3
# [Warning] Ground truth file not found for participant pair ['yb3T2', '5BJD3'] in either order.
# Leave out: yb3T2, 5KB3V
# Leave out: yb3T2, 6GSd4
# Leave out: yb3T2, 7yqP3
# Leave out: yb3T2, 9FGka
# [Warning] Ground truth file not found for participant pair ['yb3T2', '9FGka'] in either order.
# Leave out: yb3T2, A5feTy
# Leave out: yb3T2, Bs73
# Leave out: yb3T2, CVgs2
# Leave out: yb3T2, CoQmx
# Leave out: yb3T2, Cr1sTi
# Leave out: yb3T2, D9Hh9
# Leave out: yb3T2, Dwf5T
# Leave out: yb3T2, EJOiBs
# [Warning] Ground truth file not found for participant pair ['yb3T2', 'EJOiBs'] in either order.
# Leave out: yb3T2, ERqc8
# Leave out: yb3T2, EXAMPLE
# Leave out: yb3T2, F5tXL
# Leave out: yb3T2, F8mDn
# Leave out: yb3T2, Fjil72
# Leave out: yb3T2, Fk2oP
# [Warning] Ground truth file not found for participant pair ['yb3T2', 'Fk2oP'] in either order.
# Leave out: yb3T2, G4Egk
# Leave out: yb3T2, G4dLl
# Leave out: yb3T2, G5XzoP
# Leave out: yb3T2, GFGzP
# Leave out: yb3T2, GHft8
# Leave out: yb3T2, Gax8
# Leave out: yb3T2, Gftw5
# Leave out: yb3T2, Gr33d
# Leave out: yb3T2, Hx7dO
# Leave out: yb3T2, KWgkc
# Leave out: yb3T2, Kgh4P3
# Leave out: yb3T2, KoG5ii
# Leave out: yb3T2, LR96S
# Leave out: yb3T2, M4t7k
# Leave out: yb3T2, NMy2s
# Leave out: yb3T2, O1pGR
# Leave out: yb3T2, PPjCX
# Leave out: yb3T2, Pi9803
# Leave out: yb3T2, SI3pa2
# Leave out: yb3T2, V9D5x
# Leave out: yb3T2, WQzBV
# Leave out: yb3T2, WYuvqk
# Leave out: yb3T2, XPI3pA
# Leave out: yb3T2, Xd3foP9
# Leave out: yb3T2, XhsN0o
# Leave out: yb3T2, gf5X
# Leave out: yb3T2, gjGzb
# Leave out: yb3T2, h2yD5h
# Leave out: yb3T2, hMHEK1
# Leave out: yb3T2, kH4Dd
# Leave out: yb3T2, sop2d
# Leave out: yb3T2, tMGNS
# Leave out: yb3T2, urJvc
# Leave out: yb3T2, wohkw
#       IgnoredParticipant PredictedParticipant   video  pupil_pred  gsr_pred
# 0                  4FoNM                5KB3V    HN_1    0.065424 -0.027929
# 1                  4FoNM                5KB3V  HN_2_L   -0.213038 -0.255576
# 2                  4FoNM                5KB3V  HN_2_H    0.162563  0.170150
# 3                  4FoNM                5KB3V  HN_3_L   -0.053197 -0.222288
# 4                  4FoNM                5KB3V  HN_3_H    0.132339  0.149587
# ...                  ...                  ...     ...         ...       ...
# 91045              yb3T2                wohkw    LP_3    0.032432 -0.002118
# 91046              yb3T2                wohkw    LP_4    0.131316  0.178000
# 91047              yb3T2                wohkw    LP_5    0.159826  0.148282
# 91048              yb3T2                wohkw    LP_6   -0.065732 -0.216571
# 91049              yb3T2                wohkw    LP_7    0.202546  0.176484
#
# [91050 rows x 5 columns]

# %%
def run_participant_loop_arousal(df, gt_full_set, fusion_model_cls, fusion_model_kwargs={}):
    """  Runs Leave-Two-Participant-Out (L2PO) cross-validation for arousal prediction using fusion models built on previously generated modality predictions. """
    participants = df["IgnoredParticipant"].unique()
    participant_results = []
    
    fusion_weights = {}
    all_fusion_preds, all_true_values, all_test_participants = [], [], []
    rmse_per_video = []
    
    true_arousal_max = gt_full_set['Arousal'].max()
    true_arousal_min = gt_full_set['Arousal'].min()
  
    for test_pid in participants:
        train_data, test_data = get_train_test_data_fusion(df, gt_full_set, test_pid, "Arousal")
        if train_data is None or test_data is None:
            continue

        # Extract train/test labels
        y_train = train_data["Arousal"].values
        y_test = test_data["Arousal"].values

        # Get features
        fusion_X_train = train_data[["pupil_pred", "gsr_pred"]]
        fusion_X_test = test_data[["pupil_pred", "gsr_pred"]]

        # Normalize
        fusion_scaler = StandardScaler()
        fusion_X_train = fusion_scaler.fit_transform(fusion_X_train)
        fusion_X_test = fusion_scaler.transform(fusion_X_test)

        # Train fusion model
        model_fusion = fusion_model_cls(**fusion_model_kwargs)
        model_fusion.fit(fusion_X_train, y_train)
        fusion_preds = model_fusion.predict(fusion_X_test)

        # Save fusion weights if linear model used
        if hasattr(model_fusion, "coef_"):
            fusion_weights[test_pid] = model_fusion.coef_

        # Evaluate fusion model
        fusion_metrics = evaluate_fusion_model(y_test, fusion_preds)
        fusion_metrics["participant"] = test_pid

        all_metrics = {
            "participant": test_pid,
            **fusion_metrics,

        }
        
        # Adding the RMSE per video
        for video_id in test_data["video"].unique():
            mask = test_data["video"] == video_id
            y_true_video = y_test[mask]
            y_pred_video = fusion_preds[mask]
        
            if len(y_true_video) == 0 or len(y_pred_video) == 0:
                continue
        
            rmse = np.sqrt(mean_squared_error(y_true_video, y_pred_video))
        
            rmse_per_video.append({
                "Participant": test_pid,
                "Video": video_id,
                "Modality": "Fusion",
                "RMSE": rmse
            })
        participant_results.append(all_metrics)
        all_fusion_preds.extend(fusion_preds)
        all_true_values.extend(y_test)
        all_test_participants.extend([test_pid] * len(y_test))
        
    nrmse_df = pd.DataFrame(rmse_per_video)
    nrmse_df["NRMSE"] = nrmse_df["RMSE"] / (true_arousal_max - true_arousal_min)
    nrmse_df.to_csv("D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/nrmse_per_video_fusion_arousal.csv", index=False)

    return (
        participant_results,
        fusion_weights,
        all_fusion_preds,
        all_true_values,
        all_test_participants,
    )

# %% [markdown]
# **Linear Regression**

# %%
print("Linear Regression --------------- Arousal")

fusion_model_cls = LinearRegression
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_arousal(fusion_df,gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Linear Regression --------------- Arousal
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 1 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0634  0.9162  0.9574  0.0
# std   0.0040  0.0118  0.0061  0.0
#
# Excluded participants:
#   participant     NRMSE        R2      corr
# 5        Bs73  0.500908 -2.996558 -0.942155
#
# Average Fusion Weights across Participants:
# Pupil_weight    0.0328
# GSR_weight      0.1497
# dtype: float64

# %% [markdown]
# **Ridge Regression**

# %%
print("Ridge --------------- Arousal")
fusion_model_cls = Ridge
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_arousal(fusion_df, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Ridge --------------- Arousal
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 1 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0634  0.9162  0.9574  0.0
# std   0.0040  0.0118  0.0061  0.0
#
# Excluded participants:
#   participant     NRMSE        R2      corr
# 5        Bs73  0.500906 -2.996528 -0.942155
#
# Average Fusion Weights across Participants:
# Pupil_weight    0.0328
# GSR_weight      0.1497
# dtype: float64

# %% [markdown]
# **Random Forest Regressor**

# %%
print("RF Regressor -------------- Arousal")
fusion_model_cls = RandomForestRegressor
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_arousal(fusion_df,gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# RF Regressor -------------- Arousal
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 1 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0598  0.9255  0.9622  0.0
# std   0.0039  0.0106  0.0053  0.0
#
# Excluded participants:
#   participant     NRMSE        R2      corr
# 5        Bs73  0.499379 -2.972188 -0.945283

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
print("Gradient Boosting Regressor -------------- Arousal")
fusion_model_cls = GradientBoostingRegressor
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_arousal(fusion_df,gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Gradient Boosting Regressor -------------- Arousal
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 1 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0571  0.9322  0.9656  0.0
# std   0.0037  0.0099  0.0051  0.0
#
# Excluded participants:
#   participant     NRMSE        R2      corr
# 5        Bs73  0.496877 -2.932495 -0.951209

# %% [markdown]
# **SVR**

# %%
print("SVR -------------- Arousal")
fusion_model_cls = SVR
fusion_model_kwargs = {'kernel':'rbf', 'C':1.0, 'epsilon':0.1}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_arousal(fusion_df,gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# SVR -------------- Arousal
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 1 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0643  0.9141  0.9604  0.0
# std   0.0031  0.0088  0.0043  0.0
#
# Excluded participants:
#   participant     NRMSE       R2     corr
# 5        Bs73  0.512982 -3.19154 -0.95007

# %% [markdown]
# ## Valence

# %%
# Loading the pupil arousal parameters
pupil_valence_params = pd.read_csv(os.path.join(home_directory, "pupil_params_valence.csv"))

# %%
# List to collect all fusion inputs
fusion_inputs = []

participants = df["participant"].unique()

for first_p in participants:
    for second_p in participants:
        if first_p == second_p:
            continue
        
        # One participant is ignored (first_p) and one participant is predicted (second_p)
        print(f"Leave out: {first_p}, {second_p}")
        test_id = second_p

        train_data, test_data = get_train_test_data_l2po(
            df, [first_p, second_p], "Valence"
        )
        if train_data is None or test_data is None:
            continue

        y_train = train_data["Valence"].values
        y_test = test_data[test_data["participant"] == test_id]["Valence"].values
        if len(y_test) == 0:
            continue

        # ----- Pupil model -----
        X_train_pupil = train_data[pupil_features]
        X_test_pupil = test_data[pupil_features]
        
        # Make sure Participant column is treated as string
        pupil_valence_params['Participant'] = pupil_valence_params['Participant'].astype(str)

        # Convert test_pid to string for matching
        test_pid_str = str(test_id)

        # Find the participant's best params row
        participant_params_row = pupil_valence_params[pupil_valence_params['Participant'] == test_pid_str]

        if participant_params_row.empty:
            print(f"No parameters found for participant {test_pid_str}. Using default.")
            model_pupil = LGBMRegressor(objective='quantile', alpha=0.5, random_state=42)
        else:
            # Drop 'Participant' and convert remaining row to dict
            param_dict = participant_params_row.drop(columns=['Participant']).iloc[0].to_dict()

            # Convert any float to int if needed
            param_dict = {k: int(v) if isinstance(v, float) and v.is_integer() else v for k, v in param_dict.items()}

            # Add random_state and other parameters explicitly
            param_dict['random_state'] = 42
            param_dict['objective'] = 'quantile'
            param_dict['alpha'] = 0.5

            # Initialize model with participant's parameters
            model_pupil = LGBMRegressor(**param_dict)
        
        
        model_pupil.fit(X_train_pupil, y_train)
        test_pupil_preds = model_pupil.predict(X_test_pupil)

        # ----- GSR model ------
        X_train_gsr = train_data[gsr_features]
        X_test_gsr = test_data[gsr_features]
        model_gsr = StackedSvrLgbmModel(
            svr_features=gsr_modality_configs["GSR_valence"]["svr_features"],
            lgbm_features=gsr_modality_configs["GSR_valence"]["lgbm_features"],
            **gsr_modality_configs["GSR_valence"]["params"]
        )
        model_gsr.train_and_val(X_train_gsr, None, y_train)
        test_gsr_preds = model_gsr.test(X_test_gsr)

        # Store fusion inputs per row in test set (even if more than one row)
        # Get the rows corresponding to the current test participant
        test_rows = test_data[test_data["participant"] == test_id].reset_index(drop=True)
        
        for i in range(len(y_test)):
            fusion_inputs.append({
                "IgnoredParticipant": first_p,
                "PredictedParticipant": test_id,
                "video": test_rows.loc[i, "video"],
                "pupil_pred": test_pupil_preds[i],
                "gsr_pred": test_gsr_preds[i],
            })

# Convert to DataFrame
fusion_df_valence = pd.DataFrame(fusion_inputs)

print(fusion_df_valence)
# Out:
# Leave out: 22DFx, 4FoNM
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '4FoNM'] in either order.
# Leave out: 22DFx, 5BJD3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '5BJD3'] in either order.
# Leave out: 22DFx, 5KB3V
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '5KB3V'] in either order.
# Leave out: 22DFx, 6GSd4
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '6GSd4'] in either order.
# Leave out: 22DFx, 7yqP3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '7yqP3'] in either order.
# Leave out: 22DFx, 9FGka
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', '9FGka'] in either order.
# Leave out: 22DFx, A5feTy
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'A5feTy'] in either order.
# Leave out: 22DFx, Bs73
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Bs73'] in either order.
# Leave out: 22DFx, CVgs2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'CVgs2'] in either order.
# Leave out: 22DFx, CoQmx
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'CoQmx'] in either order.
# Leave out: 22DFx, Cr1sTi
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Cr1sTi'] in either order.
# Leave out: 22DFx, D9Hh9
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'D9Hh9'] in either order.
# Leave out: 22DFx, Dwf5T
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Dwf5T'] in either order.
# Leave out: 22DFx, EJOiBs
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'EJOiBs'] in either order.
# Leave out: 22DFx, ERqc8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'ERqc8'] in either order.
# Leave out: 22DFx, EXAMPLE
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'EXAMPLE'] in either order.
# Leave out: 22DFx, F5tXL
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'F5tXL'] in either order.
# Leave out: 22DFx, F8mDn
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'F8mDn'] in either order.
# Leave out: 22DFx, Fjil72
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Fjil72'] in either order.
# Leave out: 22DFx, Fk2oP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Fk2oP'] in either order.
# Leave out: 22DFx, G4Egk
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G4Egk'] in either order.
# Leave out: 22DFx, G4dLl
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G4dLl'] in either order.
# Leave out: 22DFx, G5XzoP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'G5XzoP'] in either order.
# Leave out: 22DFx, GFGzP
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'GFGzP'] in either order.
# Leave out: 22DFx, GHft8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'GHft8'] in either order.
# Leave out: 22DFx, Gax8
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gax8'] in either order.
# Leave out: 22DFx, Gftw5
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gftw5'] in either order.
# Leave out: 22DFx, Gr33d
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Gr33d'] in either order.
# Leave out: 22DFx, Hx7dO
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Hx7dO'] in either order.
# Leave out: 22DFx, KWgkc
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'KWgkc'] in either order.
# Leave out: 22DFx, Kgh4P3
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Kgh4P3'] in either order.
# Leave out: 22DFx, KoG5ii
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'KoG5ii'] in either order.
# Leave out: 22DFx, LR96S
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'LR96S'] in either order.
# Leave out: 22DFx, M4t7k
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'M4t7k'] in either order.
# Leave out: 22DFx, NMy2s
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'NMy2s'] in either order.
# Leave out: 22DFx, O1pGR
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'O1pGR'] in either order.
# Leave out: 22DFx, PPjCX
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'PPjCX'] in either order.
# Leave out: 22DFx, Pi9803
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Pi9803'] in either order.
# Leave out: 22DFx, SI3pa2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'SI3pa2'] in either order.
# Leave out: 22DFx, V9D5x
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'V9D5x'] in either order.
# Leave out: 22DFx, WQzBV
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'WQzBV'] in either order.
# Leave out: 22DFx, WYuvqk
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'WYuvqk'] in either order.
# Leave out: 22DFx, XPI3pA
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'XPI3pA'] in either order.
# Leave out: 22DFx, Xd3foP9
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'Xd3foP9'] in either order.
# Leave out: 22DFx, XhsN0o
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'XhsN0o'] in either order.
# Leave out: 22DFx, gf5X
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'gf5X'] in either order.
# Leave out: 22DFx, gjGzb
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'gjGzb'] in either order.
# Leave out: 22DFx, h2yD5h
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'h2yD5h'] in either order.
# Leave out: 22DFx, hMHEK1
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'hMHEK1'] in either order.
# Leave out: 22DFx, kH4Dd
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'kH4Dd'] in either order.
# Leave out: 22DFx, sop2d
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'sop2d'] in either order.
# Leave out: 22DFx, tMGNS
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'tMGNS'] in either order.
# Leave out: 22DFx, urJvc
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'urJvc'] in either order.
# Leave out: 22DFx, wohkw
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'wohkw'] in either order.
# Leave out: 22DFx, yb3T2
# [Warning] Ground truth file not found for participant 22DFx at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_22DFx.csv
# [Warning] Ground truth file not found for participant pair ['22DFx', 'yb3T2'] in either order.
# Leave out: 4FoNM, 22DFx
# [Warning] Ground truth file not found for participant pair ['4FoNM', '22DFx'] in either order.
# Leave out: 4FoNM, 5BJD3
# [Warning] Ground truth file not found for participant pair ['4FoNM', '5BJD3'] in either order.
# Leave out: 4FoNM, 5KB3V
# Leave out: 4FoNM, 6GSd4
# Leave out: 4FoNM, 7yqP3
# Leave out: 4FoNM, 9FGka
# [Warning] Ground truth file not found for participant pair ['4FoNM', '9FGka'] in either order.
# Leave out: 4FoNM, A5feTy
# Leave out: 4FoNM, Bs73
# Leave out: 4FoNM, CVgs2
# Leave out: 4FoNM, CoQmx
# Leave out: 4FoNM, Cr1sTi
# Leave out: 4FoNM, D9Hh9
# Leave out: 4FoNM, Dwf5T
# Leave out: 4FoNM, EJOiBs
# [Warning] Ground truth file not found for participant pair ['4FoNM', 'EJOiBs'] in either order.
# Leave out: 4FoNM, ERqc8
# Leave out: 4FoNM, EXAMPLE
# Leave out: 4FoNM, F5tXL
# Leave out: 4FoNM, F8mDn
# Leave out: 4FoNM, Fjil72
# Leave out: 4FoNM, Fk2oP
# [Warning] Ground truth file not found for participant pair ['4FoNM', 'Fk2oP'] in either order.
# Leave out: 4FoNM, G4Egk
# Leave out: 4FoNM, G4dLl
# Leave out: 4FoNM, G5XzoP
# Leave out: 4FoNM, GFGzP
# Leave out: 4FoNM, GHft8
# Leave out: 4FoNM, Gax8
# Leave out: 4FoNM, Gftw5
# Leave out: 4FoNM, Gr33d
# Leave out: 4FoNM, Hx7dO
# Leave out: 4FoNM, KWgkc
# Leave out: 4FoNM, Kgh4P3
# Leave out: 4FoNM, KoG5ii
# Leave out: 4FoNM, LR96S
# Leave out: 4FoNM, M4t7k
# Leave out: 4FoNM, NMy2s
# Leave out: 4FoNM, O1pGR
# Leave out: 4FoNM, PPjCX
# Leave out: 4FoNM, Pi9803
# Leave out: 4FoNM, SI3pa2
# Leave out: 4FoNM, V9D5x
# Leave out: 4FoNM, WQzBV
# Leave out: 4FoNM, WYuvqk
# Leave out: 4FoNM, XPI3pA
# Leave out: 4FoNM, Xd3foP9
# Leave out: 4FoNM, XhsN0o
# Leave out: 4FoNM, gf5X
# Leave out: 4FoNM, gjGzb
# Leave out: 4FoNM, h2yD5h
# Leave out: 4FoNM, hMHEK1
# Leave out: 4FoNM, kH4Dd
# Leave out: 4FoNM, sop2d
# Leave out: 4FoNM, tMGNS
# Leave out: 4FoNM, urJvc
# Leave out: 4FoNM, wohkw
# Leave out: 4FoNM, yb3T2
# Leave out: 5BJD3, 22DFx
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '22DFx'] in either order.
# Leave out: 5BJD3, 4FoNM
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '4FoNM'] in either order.
# Leave out: 5BJD3, 5KB3V
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '5KB3V'] in either order.
# Leave out: 5BJD3, 6GSd4
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '6GSd4'] in either order.
# Leave out: 5BJD3, 7yqP3
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '7yqP3'] in either order.
# Leave out: 5BJD3, 9FGka
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', '9FGka'] in either order.
# Leave out: 5BJD3, A5feTy
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'A5feTy'] in either order.
# Leave out: 5BJD3, Bs73
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Bs73'] in either order.
# Leave out: 5BJD3, CVgs2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'CVgs2'] in either order.
# Leave out: 5BJD3, CoQmx
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'CoQmx'] in either order.
# Leave out: 5BJD3, Cr1sTi
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Cr1sTi'] in either order.
# Leave out: 5BJD3, D9Hh9
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'D9Hh9'] in either order.
# Leave out: 5BJD3, Dwf5T
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Dwf5T'] in either order.
# Leave out: 5BJD3, EJOiBs
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'EJOiBs'] in either order.
# Leave out: 5BJD3, ERqc8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'ERqc8'] in either order.
# Leave out: 5BJD3, EXAMPLE
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'EXAMPLE'] in either order.
# Leave out: 5BJD3, F5tXL
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'F5tXL'] in either order.
# Leave out: 5BJD3, F8mDn
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'F8mDn'] in either order.
# Leave out: 5BJD3, Fjil72
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Fjil72'] in either order.
# Leave out: 5BJD3, Fk2oP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Fk2oP'] in either order.
# Leave out: 5BJD3, G4Egk
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G4Egk'] in either order.
# Leave out: 5BJD3, G4dLl
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G4dLl'] in either order.
# Leave out: 5BJD3, G5XzoP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'G5XzoP'] in either order.
# Leave out: 5BJD3, GFGzP
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'GFGzP'] in either order.
# Leave out: 5BJD3, GHft8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'GHft8'] in either order.
# Leave out: 5BJD3, Gax8
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gax8'] in either order.
# Leave out: 5BJD3, Gftw5
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gftw5'] in either order.
# Leave out: 5BJD3, Gr33d
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Gr33d'] in either order.
# Leave out: 5BJD3, Hx7dO
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Hx7dO'] in either order.
# Leave out: 5BJD3, KWgkc
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'KWgkc'] in either order.
# Leave out: 5BJD3, Kgh4P3
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Kgh4P3'] in either order.
# Leave out: 5BJD3, KoG5ii
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'KoG5ii'] in either order.
# Leave out: 5BJD3, LR96S
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'LR96S'] in either order.
# Leave out: 5BJD3, M4t7k
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'M4t7k'] in either order.
# Leave out: 5BJD3, NMy2s
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'NMy2s'] in either order.
# Leave out: 5BJD3, O1pGR
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'O1pGR'] in either order.
# Leave out: 5BJD3, PPjCX
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'PPjCX'] in either order.
# Leave out: 5BJD3, Pi9803
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Pi9803'] in either order.
# Leave out: 5BJD3, SI3pa2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'SI3pa2'] in either order.
# Leave out: 5BJD3, V9D5x
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'V9D5x'] in either order.
# Leave out: 5BJD3, WQzBV
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'WQzBV'] in either order.
# Leave out: 5BJD3, WYuvqk
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'WYuvqk'] in either order.
# Leave out: 5BJD3, XPI3pA
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'XPI3pA'] in either order.
# Leave out: 5BJD3, Xd3foP9
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'Xd3foP9'] in either order.
# Leave out: 5BJD3, XhsN0o
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'XhsN0o'] in either order.
# Leave out: 5BJD3, gf5X
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'gf5X'] in either order.
# Leave out: 5BJD3, gjGzb
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'gjGzb'] in either order.
# Leave out: 5BJD3, h2yD5h
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'h2yD5h'] in either order.
# Leave out: 5BJD3, hMHEK1
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'hMHEK1'] in either order.
# Leave out: 5BJD3, kH4Dd
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'kH4Dd'] in either order.
# Leave out: 5BJD3, sop2d
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'sop2d'] in either order.
# Leave out: 5BJD3, tMGNS
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'tMGNS'] in either order.
# Leave out: 5BJD3, urJvc
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'urJvc'] in either order.
# Leave out: 5BJD3, wohkw
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'wohkw'] in either order.
# Leave out: 5BJD3, yb3T2
# [Warning] Ground truth file not found for participant 5BJD3 at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_5BJD3.csv
# [Warning] Ground truth file not found for participant pair ['5BJD3', 'yb3T2'] in either order.
# Leave out: 5KB3V, 22DFx
# [Warning] Ground truth file not found for participant pair ['5KB3V', '22DFx'] in either order.
# Leave out: 5KB3V, 4FoNM
# Leave out: 5KB3V, 5BJD3
# [Warning] Ground truth file not found for participant pair ['5KB3V', '5BJD3'] in either order.
# Leave out: 5KB3V, 6GSd4
# Leave out: 5KB3V, 7yqP3
# Leave out: 5KB3V, 9FGka
# [Warning] Ground truth file not found for participant pair ['5KB3V', '9FGka'] in either order.
# Leave out: 5KB3V, A5feTy
# Leave out: 5KB3V, Bs73
# Leave out: 5KB3V, CVgs2
# Leave out: 5KB3V, CoQmx
# Leave out: 5KB3V, Cr1sTi
# Leave out: 5KB3V, D9Hh9
# Leave out: 5KB3V, Dwf5T
# Leave out: 5KB3V, EJOiBs
# [Warning] Ground truth file not found for participant pair ['5KB3V', 'EJOiBs'] in either order.
# Leave out: 5KB3V, ERqc8
# Leave out: 5KB3V, EXAMPLE
# Leave out: 5KB3V, F5tXL
# Leave out: 5KB3V, F8mDn
# Leave out: 5KB3V, Fjil72
# Leave out: 5KB3V, Fk2oP
# [Warning] Ground truth file not found for participant pair ['5KB3V', 'Fk2oP'] in either order.
# Leave out: 5KB3V, G4Egk
# Leave out: 5KB3V, G4dLl
# Leave out: 5KB3V, G5XzoP
# Leave out: 5KB3V, GFGzP
# Leave out: 5KB3V, GHft8
# Leave out: 5KB3V, Gax8
# Leave out: 5KB3V, Gftw5
# Leave out: 5KB3V, Gr33d
# Leave out: 5KB3V, Hx7dO
# Leave out: 5KB3V, KWgkc
# Leave out: 5KB3V, Kgh4P3
# Leave out: 5KB3V, KoG5ii
# Leave out: 5KB3V, LR96S
# Leave out: 5KB3V, M4t7k
# Leave out: 5KB3V, NMy2s
# Leave out: 5KB3V, O1pGR
# Leave out: 5KB3V, PPjCX
# Leave out: 5KB3V, Pi9803
# Leave out: 5KB3V, SI3pa2
# Leave out: 5KB3V, V9D5x
# Leave out: 5KB3V, WQzBV
# Leave out: 5KB3V, WYuvqk
# Leave out: 5KB3V, XPI3pA
# Leave out: 5KB3V, Xd3foP9
# Leave out: 5KB3V, XhsN0o
# Leave out: 5KB3V, gf5X
# Leave out: 5KB3V, gjGzb
# Leave out: 5KB3V, h2yD5h
# Leave out: 5KB3V, hMHEK1
# Leave out: 5KB3V, kH4Dd
# Leave out: 5KB3V, sop2d
# Leave out: 5KB3V, tMGNS
# Leave out: 5KB3V, urJvc
# Leave out: 5KB3V, wohkw
# Leave out: 5KB3V, yb3T2
# Leave out: 6GSd4, 22DFx
# [Warning] Ground truth file not found for participant pair ['6GSd4', '22DFx'] in either order.
# Leave out: 6GSd4, 4FoNM
# Leave out: 6GSd4, 5BJD3
# [Warning] Ground truth file not found for participant pair ['6GSd4', '5BJD3'] in either order.
# Leave out: 6GSd4, 5KB3V
# Leave out: 6GSd4, 7yqP3
# Leave out: 6GSd4, 9FGka
# [Warning] Ground truth file not found for participant pair ['6GSd4', '9FGka'] in either order.
# Leave out: 6GSd4, A5feTy
# Leave out: 6GSd4, Bs73
# Leave out: 6GSd4, CVgs2
# Leave out: 6GSd4, CoQmx
# Leave out: 6GSd4, Cr1sTi
# Leave out: 6GSd4, D9Hh9
# Leave out: 6GSd4, Dwf5T
# Leave out: 6GSd4, EJOiBs
# [Warning] Ground truth file not found for participant pair ['6GSd4', 'EJOiBs'] in either order.
# Leave out: 6GSd4, ERqc8
# Leave out: 6GSd4, EXAMPLE
# Leave out: 6GSd4, F5tXL
# Leave out: 6GSd4, F8mDn
# Leave out: 6GSd4, Fjil72
# Leave out: 6GSd4, Fk2oP
# [Warning] Ground truth file not found for participant pair ['6GSd4', 'Fk2oP'] in either order.
# Leave out: 6GSd4, G4Egk
# Leave out: 6GSd4, G4dLl
# Leave out: 6GSd4, G5XzoP
# Leave out: 6GSd4, GFGzP
# Leave out: 6GSd4, GHft8
# Leave out: 6GSd4, Gax8
# Leave out: 6GSd4, Gftw5
# Leave out: 6GSd4, Gr33d
# Leave out: 6GSd4, Hx7dO
# Leave out: 6GSd4, KWgkc
# Leave out: 6GSd4, Kgh4P3
# Leave out: 6GSd4, KoG5ii
# Leave out: 6GSd4, LR96S
# Leave out: 6GSd4, M4t7k
# Leave out: 6GSd4, NMy2s
# Leave out: 6GSd4, O1pGR
# Leave out: 6GSd4, PPjCX
# Leave out: 6GSd4, Pi9803
# Leave out: 6GSd4, SI3pa2
# Leave out: 6GSd4, V9D5x
# Leave out: 6GSd4, WQzBV
# Leave out: 6GSd4, WYuvqk
# Leave out: 6GSd4, XPI3pA
# Leave out: 6GSd4, Xd3foP9
# Leave out: 6GSd4, XhsN0o
# Leave out: 6GSd4, gf5X
# Leave out: 6GSd4, gjGzb
# Leave out: 6GSd4, h2yD5h
# Leave out: 6GSd4, hMHEK1
# Leave out: 6GSd4, kH4Dd
# Leave out: 6GSd4, sop2d
# Leave out: 6GSd4, tMGNS
# Leave out: 6GSd4, urJvc
# Leave out: 6GSd4, wohkw
# Leave out: 6GSd4, yb3T2
# Leave out: 7yqP3, 22DFx
# [Warning] Ground truth file not found for participant pair ['7yqP3', '22DFx'] in either order.
# Leave out: 7yqP3, 4FoNM
# Leave out: 7yqP3, 5BJD3
# [Warning] Ground truth file not found for participant pair ['7yqP3', '5BJD3'] in either order.
# Leave out: 7yqP3, 5KB3V
# Leave out: 7yqP3, 6GSd4
# Leave out: 7yqP3, 9FGka
# [Warning] Ground truth file not found for participant pair ['7yqP3', '9FGka'] in either order.
# Leave out: 7yqP3, A5feTy
# Leave out: 7yqP3, Bs73
# Leave out: 7yqP3, CVgs2
# Leave out: 7yqP3, CoQmx
# Leave out: 7yqP3, Cr1sTi
# Leave out: 7yqP3, D9Hh9
# Leave out: 7yqP3, Dwf5T
# Leave out: 7yqP3, EJOiBs
# [Warning] Ground truth file not found for participant pair ['7yqP3', 'EJOiBs'] in either order.
# Leave out: 7yqP3, ERqc8
# Leave out: 7yqP3, EXAMPLE
# Leave out: 7yqP3, F5tXL
# Leave out: 7yqP3, F8mDn
# Leave out: 7yqP3, Fjil72
# Leave out: 7yqP3, Fk2oP
# [Warning] Ground truth file not found for participant pair ['7yqP3', 'Fk2oP'] in either order.
# Leave out: 7yqP3, G4Egk
# Leave out: 7yqP3, G4dLl
# Leave out: 7yqP3, G5XzoP
# Leave out: 7yqP3, GFGzP
# Leave out: 7yqP3, GHft8
# Leave out: 7yqP3, Gax8
# Leave out: 7yqP3, Gftw5
# Leave out: 7yqP3, Gr33d
# Leave out: 7yqP3, Hx7dO
# Leave out: 7yqP3, KWgkc
# Leave out: 7yqP3, Kgh4P3
# Leave out: 7yqP3, KoG5ii
# Leave out: 7yqP3, LR96S
# Leave out: 7yqP3, M4t7k
# Leave out: 7yqP3, NMy2s
# Leave out: 7yqP3, O1pGR
# Leave out: 7yqP3, PPjCX
# Leave out: 7yqP3, Pi9803
# Leave out: 7yqP3, SI3pa2
# Leave out: 7yqP3, V9D5x
# Leave out: 7yqP3, WQzBV
# Leave out: 7yqP3, WYuvqk
# Leave out: 7yqP3, XPI3pA
# Leave out: 7yqP3, Xd3foP9
# Leave out: 7yqP3, XhsN0o
# Leave out: 7yqP3, gf5X
# Leave out: 7yqP3, gjGzb
# Leave out: 7yqP3, h2yD5h
# Leave out: 7yqP3, hMHEK1
# Leave out: 7yqP3, kH4Dd
# Leave out: 7yqP3, sop2d
# Leave out: 7yqP3, tMGNS
# Leave out: 7yqP3, urJvc
# Leave out: 7yqP3, wohkw
# Leave out: 7yqP3, yb3T2
# Leave out: 9FGka, 22DFx
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '22DFx'] in either order.
# Leave out: 9FGka, 4FoNM
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '4FoNM'] in either order.
# Leave out: 9FGka, 5BJD3
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '5BJD3'] in either order.
# Leave out: 9FGka, 5KB3V
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '5KB3V'] in either order.
# Leave out: 9FGka, 6GSd4
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '6GSd4'] in either order.
# Leave out: 9FGka, 7yqP3
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', '7yqP3'] in either order.
# Leave out: 9FGka, A5feTy
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'A5feTy'] in either order.
# Leave out: 9FGka, Bs73
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Bs73'] in either order.
# Leave out: 9FGka, CVgs2
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'CVgs2'] in either order.
# Leave out: 9FGka, CoQmx
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'CoQmx'] in either order.
# Leave out: 9FGka, Cr1sTi
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Cr1sTi'] in either order.
# Leave out: 9FGka, D9Hh9
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'D9Hh9'] in either order.
# Leave out: 9FGka, Dwf5T
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Dwf5T'] in either order.
# Leave out: 9FGka, EJOiBs
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'EJOiBs'] in either order.
# Leave out: 9FGka, ERqc8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'ERqc8'] in either order.
# Leave out: 9FGka, EXAMPLE
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'EXAMPLE'] in either order.
# Leave out: 9FGka, F5tXL
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'F5tXL'] in either order.
# Leave out: 9FGka, F8mDn
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'F8mDn'] in either order.
# Leave out: 9FGka, Fjil72
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Fjil72'] in either order.
# Leave out: 9FGka, Fk2oP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Fk2oP'] in either order.
# Leave out: 9FGka, G4Egk
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G4Egk'] in either order.
# Leave out: 9FGka, G4dLl
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G4dLl'] in either order.
# Leave out: 9FGka, G5XzoP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'G5XzoP'] in either order.
# Leave out: 9FGka, GFGzP
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'GFGzP'] in either order.
# Leave out: 9FGka, GHft8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'GHft8'] in either order.
# Leave out: 9FGka, Gax8
# [Warning] Ground truth file not found for participant 9FGka at: D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/Ground truth\Leave-one-out/individual_ground_truth_no_9FGka.csv
# [Warning] Ground truth file not found for participant pair ['9FGka', 'Gax8'] in either order.
# ...
# Leave out: gjGzb, PPjCX
# Leave out: gjGzb, Pi9803
# Leave out: gjGzb, SI3pa2
# Leave out: gjGzb, V9D5x
# Leave out: gjGzb, WQzBV
# Leave out: gjGzb, WYuvqk
# Leave out: gjGzb, XPI3pA
# Leave out: gjGzb, Xd3foP9
# Leave out: gjGzb, XhsN0o
# Leave out: gjGzb, gf5X
# Leave out: gjGzb, h2yD5h
# Leave out: gjGzb, hMHEK1
# Leave out: gjGzb, kH4Dd
# Leave out: gjGzb, sop2d
# Leave out: gjGzb, tMGNS
# Leave out: gjGzb, urJvc
# Leave out: gjGzb, wohkw
# Leave out: gjGzb, yb3T2
# Leave out: h2yD5h, 22DFx
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '22DFx'] in either order.
# Leave out: h2yD5h, 4FoNM
# Leave out: h2yD5h, 5BJD3
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '5BJD3'] in either order.
# Leave out: h2yD5h, 5KB3V
# Leave out: h2yD5h, 6GSd4
# Leave out: h2yD5h, 7yqP3
# Leave out: h2yD5h, 9FGka
# [Warning] Ground truth file not found for participant pair ['h2yD5h', '9FGka'] in either order.
# Leave out: h2yD5h, A5feTy
# Leave out: h2yD5h, Bs73
# Leave out: h2yD5h, CVgs2
# Leave out: h2yD5h, CoQmx
# Leave out: h2yD5h, Cr1sTi
# Leave out: h2yD5h, D9Hh9
# Leave out: h2yD5h, Dwf5T
# Leave out: h2yD5h, EJOiBs
# [Warning] Ground truth file not found for participant pair ['h2yD5h', 'EJOiBs'] in either order.
# Leave out: h2yD5h, ERqc8
# Leave out: h2yD5h, EXAMPLE
# Leave out: h2yD5h, F5tXL
# Leave out: h2yD5h, F8mDn
# Leave out: h2yD5h, Fjil72
# Leave out: h2yD5h, Fk2oP
# [Warning] Ground truth file not found for participant pair ['h2yD5h', 'Fk2oP'] in either order.
# Leave out: h2yD5h, G4Egk
# Leave out: h2yD5h, G4dLl
# Leave out: h2yD5h, G5XzoP
# Leave out: h2yD5h, GFGzP
# Leave out: h2yD5h, GHft8
# Leave out: h2yD5h, Gax8
# Leave out: h2yD5h, Gftw5
# Leave out: h2yD5h, Gr33d
# Leave out: h2yD5h, Hx7dO
# Leave out: h2yD5h, KWgkc
# Leave out: h2yD5h, Kgh4P3
# Leave out: h2yD5h, KoG5ii
# Leave out: h2yD5h, LR96S
# Leave out: h2yD5h, M4t7k
# Leave out: h2yD5h, NMy2s
# Leave out: h2yD5h, O1pGR
# Leave out: h2yD5h, PPjCX
# Leave out: h2yD5h, Pi9803
# Leave out: h2yD5h, SI3pa2
# Leave out: h2yD5h, V9D5x
# Leave out: h2yD5h, WQzBV
# Leave out: h2yD5h, WYuvqk
# Leave out: h2yD5h, XPI3pA
# Leave out: h2yD5h, Xd3foP9
# Leave out: h2yD5h, XhsN0o
# Leave out: h2yD5h, gf5X
# Leave out: h2yD5h, gjGzb
# Leave out: h2yD5h, hMHEK1
# Leave out: h2yD5h, kH4Dd
# Leave out: h2yD5h, sop2d
# Leave out: h2yD5h, tMGNS
# Leave out: h2yD5h, urJvc
# Leave out: h2yD5h, wohkw
# Leave out: h2yD5h, yb3T2
# Leave out: hMHEK1, 22DFx
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '22DFx'] in either order.
# Leave out: hMHEK1, 4FoNM
# Leave out: hMHEK1, 5BJD3
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '5BJD3'] in either order.
# Leave out: hMHEK1, 5KB3V
# Leave out: hMHEK1, 6GSd4
# Leave out: hMHEK1, 7yqP3
# Leave out: hMHEK1, 9FGka
# [Warning] Ground truth file not found for participant pair ['hMHEK1', '9FGka'] in either order.
# Leave out: hMHEK1, A5feTy
# Leave out: hMHEK1, Bs73
# Leave out: hMHEK1, CVgs2
# Leave out: hMHEK1, CoQmx
# Leave out: hMHEK1, Cr1sTi
# Leave out: hMHEK1, D9Hh9
# Leave out: hMHEK1, Dwf5T
# Leave out: hMHEK1, EJOiBs
# [Warning] Ground truth file not found for participant pair ['hMHEK1', 'EJOiBs'] in either order.
# Leave out: hMHEK1, ERqc8
# Leave out: hMHEK1, EXAMPLE
# Leave out: hMHEK1, F5tXL
# Leave out: hMHEK1, F8mDn
# Leave out: hMHEK1, Fjil72
# Leave out: hMHEK1, Fk2oP
# [Warning] Ground truth file not found for participant pair ['hMHEK1', 'Fk2oP'] in either order.
# Leave out: hMHEK1, G4Egk
# Leave out: hMHEK1, G4dLl
# Leave out: hMHEK1, G5XzoP
# Leave out: hMHEK1, GFGzP
# Leave out: hMHEK1, GHft8
# Leave out: hMHEK1, Gax8
# Leave out: hMHEK1, Gftw5
# Leave out: hMHEK1, Gr33d
# Leave out: hMHEK1, Hx7dO
# Leave out: hMHEK1, KWgkc
# Leave out: hMHEK1, Kgh4P3
# Leave out: hMHEK1, KoG5ii
# Leave out: hMHEK1, LR96S
# Leave out: hMHEK1, M4t7k
# Leave out: hMHEK1, NMy2s
# Leave out: hMHEK1, O1pGR
# Leave out: hMHEK1, PPjCX
# Leave out: hMHEK1, Pi9803
# Leave out: hMHEK1, SI3pa2
# Leave out: hMHEK1, V9D5x
# Leave out: hMHEK1, WQzBV
# Leave out: hMHEK1, WYuvqk
# Leave out: hMHEK1, XPI3pA
# Leave out: hMHEK1, Xd3foP9
# Leave out: hMHEK1, XhsN0o
# Leave out: hMHEK1, gf5X
# Leave out: hMHEK1, gjGzb
# Leave out: hMHEK1, h2yD5h
# Leave out: hMHEK1, kH4Dd
# Leave out: hMHEK1, sop2d
# Leave out: hMHEK1, tMGNS
# Leave out: hMHEK1, urJvc
# Leave out: hMHEK1, wohkw
# Leave out: hMHEK1, yb3T2
# Leave out: kH4Dd, 22DFx
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '22DFx'] in either order.
# Leave out: kH4Dd, 4FoNM
# Leave out: kH4Dd, 5BJD3
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '5BJD3'] in either order.
# Leave out: kH4Dd, 5KB3V
# Leave out: kH4Dd, 6GSd4
# Leave out: kH4Dd, 7yqP3
# Leave out: kH4Dd, 9FGka
# [Warning] Ground truth file not found for participant pair ['kH4Dd', '9FGka'] in either order.
# Leave out: kH4Dd, A5feTy
# Leave out: kH4Dd, Bs73
# Leave out: kH4Dd, CVgs2
# Leave out: kH4Dd, CoQmx
# Leave out: kH4Dd, Cr1sTi
# Leave out: kH4Dd, D9Hh9
# Leave out: kH4Dd, Dwf5T
# Leave out: kH4Dd, EJOiBs
# [Warning] Ground truth file not found for participant pair ['kH4Dd', 'EJOiBs'] in either order.
# Leave out: kH4Dd, ERqc8
# Leave out: kH4Dd, EXAMPLE
# Leave out: kH4Dd, F5tXL
# Leave out: kH4Dd, F8mDn
# Leave out: kH4Dd, Fjil72
# Leave out: kH4Dd, Fk2oP
# [Warning] Ground truth file not found for participant pair ['kH4Dd', 'Fk2oP'] in either order.
# Leave out: kH4Dd, G4Egk
# Leave out: kH4Dd, G4dLl
# Leave out: kH4Dd, G5XzoP
# Leave out: kH4Dd, GFGzP
# Leave out: kH4Dd, GHft8
# Leave out: kH4Dd, Gax8
# Leave out: kH4Dd, Gftw5
# Leave out: kH4Dd, Gr33d
# Leave out: kH4Dd, Hx7dO
# Leave out: kH4Dd, KWgkc
# Leave out: kH4Dd, Kgh4P3
# Leave out: kH4Dd, KoG5ii
# Leave out: kH4Dd, LR96S
# Leave out: kH4Dd, M4t7k
# Leave out: kH4Dd, NMy2s
# Leave out: kH4Dd, O1pGR
# Leave out: kH4Dd, PPjCX
# Leave out: kH4Dd, Pi9803
# Leave out: kH4Dd, SI3pa2
# Leave out: kH4Dd, V9D5x
# Leave out: kH4Dd, WQzBV
# Leave out: kH4Dd, WYuvqk
# Leave out: kH4Dd, XPI3pA
# Leave out: kH4Dd, Xd3foP9
# Leave out: kH4Dd, XhsN0o
# Leave out: kH4Dd, gf5X
# Leave out: kH4Dd, gjGzb
# Leave out: kH4Dd, h2yD5h
# Leave out: kH4Dd, hMHEK1
# Leave out: kH4Dd, sop2d
# Leave out: kH4Dd, tMGNS
# Leave out: kH4Dd, urJvc
# Leave out: kH4Dd, wohkw
# Leave out: kH4Dd, yb3T2
# Leave out: sop2d, 22DFx
# [Warning] Ground truth file not found for participant pair ['sop2d', '22DFx'] in either order.
# Leave out: sop2d, 4FoNM
# Leave out: sop2d, 5BJD3
# [Warning] Ground truth file not found for participant pair ['sop2d', '5BJD3'] in either order.
# Leave out: sop2d, 5KB3V
# Leave out: sop2d, 6GSd4
# Leave out: sop2d, 7yqP3
# Leave out: sop2d, 9FGka
# [Warning] Ground truth file not found for participant pair ['sop2d', '9FGka'] in either order.
# Leave out: sop2d, A5feTy
# Leave out: sop2d, Bs73
# Leave out: sop2d, CVgs2
# Leave out: sop2d, CoQmx
# Leave out: sop2d, Cr1sTi
# Leave out: sop2d, D9Hh9
# Leave out: sop2d, Dwf5T
# Leave out: sop2d, EJOiBs
# [Warning] Ground truth file not found for participant pair ['sop2d', 'EJOiBs'] in either order.
# Leave out: sop2d, ERqc8
# Leave out: sop2d, EXAMPLE
# Leave out: sop2d, F5tXL
# Leave out: sop2d, F8mDn
# Leave out: sop2d, Fjil72
# Leave out: sop2d, Fk2oP
# [Warning] Ground truth file not found for participant pair ['sop2d', 'Fk2oP'] in either order.
# Leave out: sop2d, G4Egk
# Leave out: sop2d, G4dLl
# Leave out: sop2d, G5XzoP
# Leave out: sop2d, GFGzP
# Leave out: sop2d, GHft8
# Leave out: sop2d, Gax8
# Leave out: sop2d, Gftw5
# Leave out: sop2d, Gr33d
# Leave out: sop2d, Hx7dO
# Leave out: sop2d, KWgkc
# Leave out: sop2d, Kgh4P3
# Leave out: sop2d, KoG5ii
# Leave out: sop2d, LR96S
# Leave out: sop2d, M4t7k
# Leave out: sop2d, NMy2s
# Leave out: sop2d, O1pGR
# Leave out: sop2d, PPjCX
# Leave out: sop2d, Pi9803
# Leave out: sop2d, SI3pa2
# Leave out: sop2d, V9D5x
# Leave out: sop2d, WQzBV
# Leave out: sop2d, WYuvqk
# Leave out: sop2d, XPI3pA
# Leave out: sop2d, Xd3foP9
# Leave out: sop2d, XhsN0o
# Leave out: sop2d, gf5X
# Leave out: sop2d, gjGzb
# Leave out: sop2d, h2yD5h
# Leave out: sop2d, hMHEK1
# Leave out: sop2d, kH4Dd
# Leave out: sop2d, tMGNS
# Leave out: sop2d, urJvc
# Leave out: sop2d, wohkw
# Leave out: sop2d, yb3T2
# Leave out: tMGNS, 22DFx
# [Warning] Ground truth file not found for participant pair ['tMGNS', '22DFx'] in either order.
# Leave out: tMGNS, 4FoNM
# Leave out: tMGNS, 5BJD3
# [Warning] Ground truth file not found for participant pair ['tMGNS', '5BJD3'] in either order.
# Leave out: tMGNS, 5KB3V
# Leave out: tMGNS, 6GSd4
# Leave out: tMGNS, 7yqP3
# Leave out: tMGNS, 9FGka
# [Warning] Ground truth file not found for participant pair ['tMGNS', '9FGka'] in either order.
# Leave out: tMGNS, A5feTy
# Leave out: tMGNS, Bs73
# Leave out: tMGNS, CVgs2
# Leave out: tMGNS, CoQmx
# Leave out: tMGNS, Cr1sTi
# Leave out: tMGNS, D9Hh9
# Leave out: tMGNS, Dwf5T
# Leave out: tMGNS, EJOiBs
# [Warning] Ground truth file not found for participant pair ['tMGNS', 'EJOiBs'] in either order.
# Leave out: tMGNS, ERqc8
# Leave out: tMGNS, EXAMPLE
# Leave out: tMGNS, F5tXL
# Leave out: tMGNS, F8mDn
# Leave out: tMGNS, Fjil72
# Leave out: tMGNS, Fk2oP
# [Warning] Ground truth file not found for participant pair ['tMGNS', 'Fk2oP'] in either order.
# Leave out: tMGNS, G4Egk
# Leave out: tMGNS, G4dLl
# Leave out: tMGNS, G5XzoP
# Leave out: tMGNS, GFGzP
# Leave out: tMGNS, GHft8
# Leave out: tMGNS, Gax8
# Leave out: tMGNS, Gftw5
# Leave out: tMGNS, Gr33d
# Leave out: tMGNS, Hx7dO
# Leave out: tMGNS, KWgkc
# Leave out: tMGNS, Kgh4P3
# Leave out: tMGNS, KoG5ii
# Leave out: tMGNS, LR96S
# Leave out: tMGNS, M4t7k
# Leave out: tMGNS, NMy2s
# Leave out: tMGNS, O1pGR
# Leave out: tMGNS, PPjCX
# Leave out: tMGNS, Pi9803
# Leave out: tMGNS, SI3pa2
# Leave out: tMGNS, V9D5x
# Leave out: tMGNS, WQzBV
# Leave out: tMGNS, WYuvqk
# Leave out: tMGNS, XPI3pA
# Leave out: tMGNS, Xd3foP9
# Leave out: tMGNS, XhsN0o
# Leave out: tMGNS, gf5X
# Leave out: tMGNS, gjGzb
# Leave out: tMGNS, h2yD5h
# Leave out: tMGNS, hMHEK1
# Leave out: tMGNS, kH4Dd
# Leave out: tMGNS, sop2d
# Leave out: tMGNS, urJvc
# Leave out: tMGNS, wohkw
# Leave out: tMGNS, yb3T2
# Leave out: urJvc, 22DFx
# [Warning] Ground truth file not found for participant pair ['urJvc', '22DFx'] in either order.
# Leave out: urJvc, 4FoNM
# Leave out: urJvc, 5BJD3
# [Warning] Ground truth file not found for participant pair ['urJvc', '5BJD3'] in either order.
# Leave out: urJvc, 5KB3V
# Leave out: urJvc, 6GSd4
# Leave out: urJvc, 7yqP3
# Leave out: urJvc, 9FGka
# [Warning] Ground truth file not found for participant pair ['urJvc', '9FGka'] in either order.
# Leave out: urJvc, A5feTy
# Leave out: urJvc, Bs73
# Leave out: urJvc, CVgs2
# Leave out: urJvc, CoQmx
# Leave out: urJvc, Cr1sTi
# Leave out: urJvc, D9Hh9
# Leave out: urJvc, Dwf5T
# Leave out: urJvc, EJOiBs
# [Warning] Ground truth file not found for participant pair ['urJvc', 'EJOiBs'] in either order.
# Leave out: urJvc, ERqc8
# Leave out: urJvc, EXAMPLE
# Leave out: urJvc, F5tXL
# Leave out: urJvc, F8mDn
# Leave out: urJvc, Fjil72
# Leave out: urJvc, Fk2oP
# [Warning] Ground truth file not found for participant pair ['urJvc', 'Fk2oP'] in either order.
# Leave out: urJvc, G4Egk
# Leave out: urJvc, G4dLl
# Leave out: urJvc, G5XzoP
# Leave out: urJvc, GFGzP
# Leave out: urJvc, GHft8
# Leave out: urJvc, Gax8
# Leave out: urJvc, Gftw5
# Leave out: urJvc, Gr33d
# Leave out: urJvc, Hx7dO
# Leave out: urJvc, KWgkc
# Leave out: urJvc, Kgh4P3
# Leave out: urJvc, KoG5ii
# Leave out: urJvc, LR96S
# Leave out: urJvc, M4t7k
# Leave out: urJvc, NMy2s
# Leave out: urJvc, O1pGR
# Leave out: urJvc, PPjCX
# Leave out: urJvc, Pi9803
# Leave out: urJvc, SI3pa2
# Leave out: urJvc, V9D5x
# Leave out: urJvc, WQzBV
# Leave out: urJvc, WYuvqk
# Leave out: urJvc, XPI3pA
# Leave out: urJvc, Xd3foP9
# Leave out: urJvc, XhsN0o
# Leave out: urJvc, gf5X
# Leave out: urJvc, gjGzb
# Leave out: urJvc, h2yD5h
# Leave out: urJvc, hMHEK1
# Leave out: urJvc, kH4Dd
# Leave out: urJvc, sop2d
# Leave out: urJvc, tMGNS
# Leave out: urJvc, wohkw
# Leave out: urJvc, yb3T2
# Leave out: wohkw, 22DFx
# [Warning] Ground truth file not found for participant pair ['wohkw', '22DFx'] in either order.
# Leave out: wohkw, 4FoNM
# Leave out: wohkw, 5BJD3
# [Warning] Ground truth file not found for participant pair ['wohkw', '5BJD3'] in either order.
# Leave out: wohkw, 5KB3V
# Leave out: wohkw, 6GSd4
# Leave out: wohkw, 7yqP3
# Leave out: wohkw, 9FGka
# [Warning] Ground truth file not found for participant pair ['wohkw', '9FGka'] in either order.
# Leave out: wohkw, A5feTy
# Leave out: wohkw, Bs73
# Leave out: wohkw, CVgs2
# Leave out: wohkw, CoQmx
# Leave out: wohkw, Cr1sTi
# Leave out: wohkw, D9Hh9
# Leave out: wohkw, Dwf5T
# Leave out: wohkw, EJOiBs
# [Warning] Ground truth file not found for participant pair ['wohkw', 'EJOiBs'] in either order.
# Leave out: wohkw, ERqc8
# Leave out: wohkw, EXAMPLE
# Leave out: wohkw, F5tXL
# Leave out: wohkw, F8mDn
# Leave out: wohkw, Fjil72
# Leave out: wohkw, Fk2oP
# [Warning] Ground truth file not found for participant pair ['wohkw', 'Fk2oP'] in either order.
# Leave out: wohkw, G4Egk
# Leave out: wohkw, G4dLl
# Leave out: wohkw, G5XzoP
# Leave out: wohkw, GFGzP
# Leave out: wohkw, GHft8
# Leave out: wohkw, Gax8
# Leave out: wohkw, Gftw5
# Leave out: wohkw, Gr33d
# Leave out: wohkw, Hx7dO
# Leave out: wohkw, KWgkc
# Leave out: wohkw, Kgh4P3
# Leave out: wohkw, KoG5ii
# Leave out: wohkw, LR96S
# Leave out: wohkw, M4t7k
# Leave out: wohkw, NMy2s
# Leave out: wohkw, O1pGR
# Leave out: wohkw, PPjCX
# Leave out: wohkw, Pi9803
# Leave out: wohkw, SI3pa2
# Leave out: wohkw, V9D5x
# Leave out: wohkw, WQzBV
# Leave out: wohkw, WYuvqk
# Leave out: wohkw, XPI3pA
# Leave out: wohkw, Xd3foP9
# Leave out: wohkw, XhsN0o
# Leave out: wohkw, gf5X
# Leave out: wohkw, gjGzb
# Leave out: wohkw, h2yD5h
# Leave out: wohkw, hMHEK1
# Leave out: wohkw, kH4Dd
# Leave out: wohkw, sop2d
# Leave out: wohkw, tMGNS
# Leave out: wohkw, urJvc
# Leave out: wohkw, yb3T2
# Leave out: yb3T2, 22DFx
# [Warning] Ground truth file not found for participant pair ['yb3T2', '22DFx'] in either order.
# Leave out: yb3T2, 4FoNM
# Leave out: yb3T2, 5BJD3
# [Warning] Ground truth file not found for participant pair ['yb3T2', '5BJD3'] in either order.
# Leave out: yb3T2, 5KB3V
# Leave out: yb3T2, 6GSd4
# Leave out: yb3T2, 7yqP3
# Leave out: yb3T2, 9FGka
# [Warning] Ground truth file not found for participant pair ['yb3T2', '9FGka'] in either order.
# Leave out: yb3T2, A5feTy
# Leave out: yb3T2, Bs73
# Leave out: yb3T2, CVgs2
# Leave out: yb3T2, CoQmx
# Leave out: yb3T2, Cr1sTi
# Leave out: yb3T2, D9Hh9
# Leave out: yb3T2, Dwf5T
# Leave out: yb3T2, EJOiBs
# [Warning] Ground truth file not found for participant pair ['yb3T2', 'EJOiBs'] in either order.
# Leave out: yb3T2, ERqc8
# Leave out: yb3T2, EXAMPLE
# Leave out: yb3T2, F5tXL
# Leave out: yb3T2, F8mDn
# Leave out: yb3T2, Fjil72
# Leave out: yb3T2, Fk2oP
# [Warning] Ground truth file not found for participant pair ['yb3T2', 'Fk2oP'] in either order.
# Leave out: yb3T2, G4Egk
# Leave out: yb3T2, G4dLl
# Leave out: yb3T2, G5XzoP
# Leave out: yb3T2, GFGzP
# Leave out: yb3T2, GHft8
# Leave out: yb3T2, Gax8
# Leave out: yb3T2, Gftw5
# Leave out: yb3T2, Gr33d
# Leave out: yb3T2, Hx7dO
# Leave out: yb3T2, KWgkc
# Leave out: yb3T2, Kgh4P3
# Leave out: yb3T2, KoG5ii
# Leave out: yb3T2, LR96S
# Leave out: yb3T2, M4t7k
# Leave out: yb3T2, NMy2s
# Leave out: yb3T2, O1pGR
# Leave out: yb3T2, PPjCX
# Leave out: yb3T2, Pi9803
# Leave out: yb3T2, SI3pa2
# Leave out: yb3T2, V9D5x
# Leave out: yb3T2, WQzBV
# Leave out: yb3T2, WYuvqk
# Leave out: yb3T2, XPI3pA
# Leave out: yb3T2, Xd3foP9
# Leave out: yb3T2, XhsN0o
# Leave out: yb3T2, gf5X
# Leave out: yb3T2, gjGzb
# Leave out: yb3T2, h2yD5h
# Leave out: yb3T2, hMHEK1
# Leave out: yb3T2, kH4Dd
# Leave out: yb3T2, sop2d
# Leave out: yb3T2, tMGNS
# Leave out: yb3T2, urJvc
# Leave out: yb3T2, wohkw
#       IgnoredParticipant PredictedParticipant   video  pupil_pred  gsr_pred
# 0                  4FoNM                5KB3V    HN_1   -0.169767 -0.708851
# 1                  4FoNM                5KB3V  HN_2_L   -0.130670 -0.094508
# 2                  4FoNM                5KB3V  HN_2_H   -0.332169 -0.456602
# 3                  4FoNM                5KB3V  HN_3_L   -0.327606 -0.056219
# 4                  4FoNM                5KB3V  HN_3_H   -0.318090 -0.303398
# ...                  ...                  ...     ...         ...       ...
# 91045              yb3T2                wohkw    LP_3    0.213119  0.155634
# 91046              yb3T2                wohkw    LP_4   -0.001932  0.387497
# 91047              yb3T2                wohkw    LP_5    0.376042  0.401043
# 91048              yb3T2                wohkw    LP_6    0.218301  0.190203
# 91049              yb3T2                wohkw    LP_7    0.191187  0.170917
#
# [91050 rows x 5 columns]

# %%
def run_participant_loop_valence(df, gt_full_set, fusion_model_cls, fusion_model_kwargs={}):
    """  Runs Leave-Two-Participant-Out (L2PO) cross-validation for arousal prediction using fusion models built on previously generated modality predictions."""
    participants = df["IgnoredParticipant"].unique()
    participant_results = []
    fusion_weights = {}
    all_fusion_preds, all_true_values, all_test_participants = [], [], []
    rmse_per_video = []
    true_valence_max = gt_full_set['Valence'].max()
    true_valence_min = gt_full_set['Valence'].min()
    for test_pid in participants:
        train_data, test_data = get_train_test_data_fusion(df, gt_full_set, test_pid, "Valence")
        if train_data is None or test_data is None:
            continue

        # Extract train/test labels
        y_train = train_data["Valence"].values
        y_test = test_data["Valence"].values

        # Get features
        fusion_X_train = train_data[["pupil_pred", "gsr_pred"]]
        fusion_X_test = test_data[["pupil_pred", "gsr_pred"]]

        # Normalize
        fusion_scaler = StandardScaler()
        fusion_X_train = fusion_scaler.fit_transform(fusion_X_train)
        fusion_X_test = fusion_scaler.transform(fusion_X_test)

        # Train fusion model
        model_fusion = fusion_model_cls(**fusion_model_kwargs)
        model_fusion.fit(fusion_X_train, y_train)
        fusion_preds = model_fusion.predict(fusion_X_test)

        # Save fusion weights if linear model used
        if hasattr(model_fusion, "coef_"):
            fusion_weights[test_pid] = model_fusion.coef_

        # Evaluate fusion model
        fusion_metrics = evaluate_fusion_model(y_test, fusion_preds)
        fusion_metrics["participant"] = test_pid

        all_metrics = {
            "participant": test_pid,
            **fusion_metrics,

        }
        
        # Add RMSE per video
        for video_id in test_data["video"].unique():
            mask = test_data["video"] == video_id
            y_true_video = y_test[mask]
            y_pred_video = fusion_preds[mask]
        
            if len(y_true_video) == 0 or len(y_pred_video) == 0:
                continue
        
            rmse = np.sqrt(mean_squared_error(y_true_video, y_pred_video))
        
            rmse_per_video.append({
                "Participant": test_pid,
                "Video": video_id,
                "Modality": "Fusion",
                "RMSE": rmse
            })
            
        participant_results.append(all_metrics)
        all_fusion_preds.extend(fusion_preds)
        all_true_values.extend(y_test)
        all_test_participants.extend([test_pid] * len(y_test))
        
    nrmse_df = pd.DataFrame(rmse_per_video)
    nrmse_df["NRMSE"] = nrmse_df["RMSE"] / (true_valence_max - true_valence_min)
    nrmse_df.to_csv("D:/MASTER/Uni of Essex/Disseration/Data-Multimotion/nrmse_per_video_fusion_valence.csv", index=False)
    
    return (
        participant_results,
        fusion_weights,
        all_fusion_preds,
        all_true_values,
        all_test_participants,
    )

# %% [markdown]
# **Linear Regression**

# %%
print("Linear Regression --------------- Valence")

fusion_model_cls = LinearRegression
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_valence(fusion_df_valence, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Linear Regression --------------- Valence
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 0 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0855  0.8636  0.9295  0.0
# std   0.0016  0.0047  0.0025  0.0
#
# Excluded participants:
# Empty DataFrame
# Columns: [participant, NRMSE, R2, corr]
# Index: []
#
# Average Fusion Weights across Participants:
# Pupil_weight    0.0604
# GSR_weight      0.2744
# dtype: float64

# %% [markdown]
# **Ridge Valence**

# %%
print("Ridge --------------- Valence")
fusion_model_cls = Ridge
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_valence(fusion_df_valence, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Ridge --------------- Valence
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 0 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0855  0.8636  0.9295  0.0
# std   0.0016  0.0047  0.0025  0.0
#
# Excluded participants:
# Empty DataFrame
# Columns: [participant, NRMSE, R2, corr]
# Index: []
#
# Average Fusion Weights across Participants:
# Pupil_weight    0.0604
# GSR_weight      0.2744
# dtype: float64

# %% [markdown]
# **Random Forest Regressor**

# %%
print("RF Regressor -------------- Valence")
fusion_model_cls = RandomForestRegressor
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_valence(fusion_df_valence, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# RF Regressor -------------- Valence
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 0 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0813  0.8764  0.9364  0.0
# std   0.0023  0.0069  0.0036  0.0
#
# Excluded participants:
# Empty DataFrame
# Columns: [participant, NRMSE, R2, corr]
# Index: []

# %% [markdown]
# **Gradient Boosting Regressor**

# %%
print("Gradient Boosting Regressor -------------- Valence")
fusion_model_cls = GradientBoostingRegressor
fusion_model_kwargs = {}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_valence(fusion_df_valence, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# Gradient Boosting Regressor -------------- Valence
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 0 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0768  0.8897  0.9433  0.0
# std   0.0018  0.0048  0.0025  0.0
#
# Excluded participants:
# Empty DataFrame
# Columns: [participant, NRMSE, R2, corr]
# Index: []

# %% [markdown]
# **SVR**

# %%
print("SVR -------------- Valence")
fusion_model_cls = SVR
fusion_model_kwargs = {'kernel':'rbf', 'C':1.0, 'epsilon':0.1}

participant_results, fusion_weights, all_fusion_preds, all_true_values, all_test_participants = run_participant_loop_valence(fusion_df_valence, gt_full_set, fusion_model_cls, fusion_model_kwargs)

results_df = pd.DataFrame(participant_results)
print_filtered_summary(results_df)
print_fusion_weights_summary(fusion_weights)
# Out:
# SVR -------------- Valence
#
# === Summary (Excluding Outliers) ===
#
# Filtered out 0 out of 51 participants.
#        NRMSE      R2    corr    p
# mean  0.0780  0.8863  0.9416  0.0
# std   0.0016  0.0045  0.0024  0.0
#
# Excluded participants:
# Empty DataFrame
# Columns: [participant, NRMSE, R2, corr]
# Index: []
